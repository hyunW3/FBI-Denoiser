# %%
import cv2
import imageio
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import SimpleITK as sitk
from core.get_args import get_args
from core.produce_denoised_img import produce_denoised_img_no_crop

# %%
# !ls /mnt/ssd/hyun/fbi-net/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU/[SET\ 1]/F64/
# Out:
# 10_F64.png  13_F64.png	16_F64.png  3_F64.png  6_F64.png  9_F64.png
# 11_F64.png  14_F64.png	1_F64.png   4_F64.png  7_F64.png
# 12_F64.png  15_F64.png	2_F64.png   5_F64.png  8_F64.png

# %%
# a_path ="/mnt/ssd/hyun/fbi-net/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung+SNU+dataset+221115/[SET 9]/F16/2_F16.png"
b_path ="/mnt/ssd/hyun/fbi-net/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung+SNU+dataset+221115/[SET 9]/F64/2_F64.png"
a_path = "/mnt/ssd/hyun/fbi-net/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU/[SET 1]/F8/1_F8.png"
# b_path = "/mnt/ssd/hyun/fbi-net/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU/[SET 1]/F64/1_F64.png"
a = cv2.imread(a_path, cv2.IMREAD_GRAYSCALE)
b = cv2.imread(b_path, cv2.IMREAD_GRAYSCALE)

# %%
plt.plot(a[100,:200])

# %%
plt.plot(a[400,:500])

# %%
a[400,:500][260:300]
# Out:
# array([211, 144, 105,  89, 140, 130,  46, 135, 141, 130, 120, 151, 168,
#        144,  95,  91, 102, 155, 113,  53,  23,  90, 114, 102,  55,  54,
#         49,  56,  12,  64,  38,  61,  32, 108,  90,  96, 121, 197, 174,
#        142], dtype=uint8)

# %%
plt.imshow(a)
plt.axhline(400,color='r')

# %%
plt.imshow(b,alpha=0.3)
plt.imshow(a,alpha=0.3)

# %%
resultImage = sitk.Elastix(sitk.ReadImage(b_path), \
                           sitk.ReadImage(a_path), \
                           "translation")
resultImage = np.array(resultImage).reshape((2048,3072))

# %%
resultImage = resultImage.reshape((2048,3072))
plt.imshow(resultImage)

# %%
plt.imshow(a)

# %%
plt.imshow(b,alpha=0.3)
plt.imshow(resultImage,alpha=0.3)

# %%
plt.imshow(b,alpha=0.3)
plt.imshow(a,alpha=0.3)

# %%
plt.imshow(a)

# %%
plt.imshow(resultImage)

# %%
plt.imshow(b)
