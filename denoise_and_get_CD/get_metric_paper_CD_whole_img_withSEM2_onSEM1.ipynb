# %%
import os 
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1" # "0,1,2,3" # "0"

# %%
import torch
import numpy as np
import h5py
import cv2
import PIL
import os, sys, gc
import argparse
from glob import glob
from core.get_args import get_args
from core.produce_denoised_img import produce_denoised_img_no_crop
from core.utils import TedataLoader
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from core.watershed import watershed,watershed_per_img,watershed_original
from core.median_filter import apply_median_filter_cpu, apply_median_filter_gpu, apply_median_filter_gpu_simple
# %load_ext autoreload
# %autoreload 2

# %%
def save_eps(img,path):
    if type(img) == torch.Tensor:
        img = img.cpu().numpy()
    img = (img-img.min())/(img.max()-img.min())
    img = PIL.Image.fromarray((img*255).astype('uint8'))
    img.save(path,dpi=(300,300),mode='EPS')

# %%
folder_name = "./N2N_output_230917_wholeimg_withSEM2_onSEM1/"
os.makedirs(folder_name, exist_ok=True)

# %%
def load_img_dict(target_x,target_y,debug=True):
    possible_f_num = ['F01','F02','F04','F08','F16','F32']
    x_f_num = []
    if target_x == 'F#':
        for f_num in possible_f_num:
            if f_num != target_y:
                x_f_num.append(f_num)
            else :
                break
    else :
        x_f_num = [target_x]
    x_f_num.append('F32')
    x_f_num.append('F64')
    print(x_f_num)
    img_dict = {}
    path_list = ["/home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU",
                 "/home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung+SNU+dataset+221115"
                 ]
    # data_path = "/mnt/ssd/hyun/fbi-net/FBI-Denoiser/data/Samsung_SNU_1474x3010_aligned_ordered/" 
    debug = True
    for data_path in path_list:
        print("=====",data_path, "=====")
        for set_num in sorted(os.listdir(data_path)):
            if set_num[0] == '.' :
                continue
            set_path = os.path.join(data_path,set_num)
            set_number = int(set_num.split(" ")[-1][:-1])
            set_num = f"{set_num[1:4]}{set_number:02d}"
            print("=====",set_num, "=====")
            img_dict[set_num] = {}
            # if debug is True:
            #     print(set_num)
            f_num_list = os.listdir(set_path)
            print(f_num_list)
            for f_num in f_num_list:
                f_path = os.path.join(set_path,f_num)
                f_number = int(f_num[1:])
                f_num = f"F{f_number:02d}"
                # print(set_num,f_num)
                if f_num not in x_f_num:
                    print(f_num , " is not in ", x_f_num)
                    continue
                # img_dict[set_num][f_num] = None
                img_dict[set_num][f_num] = {}
                img_list = sorted(os.listdir(f_path))
                img_list = list(filter(lambda x : ".ipynb_checkpoints" not in x,img_list))
                
                for filename in sorted(img_list):
                    
                    img_path = os.path.join(f_path,filename)
                    image_idx = int(filename.split("_")[0])
                    filename = f"{set_num}_{f_num}_{image_idx:02d}.png"
                    if debug is True:
                        print(f_num," & ",filename)
                    img = cv2.imread(img_path,cv2.IMREAD_GRAYSCALE) 
                    # img_dict[set_num][f_num].append(img)
                    # img = np.expand_dims(img,axis=0)
                    img = np.expand_dims(img,axis=0) / 255.
                    img_dict[set_num][f_num][filename] = img
                    # if img_dict[set_num][f_num] is None:  
                    #     img_dict[set_num][f_num] = img
                    # else :
                    #     img_dict[set_num][f_num] = np.append(img_dict[set_num][f_num],img,axis=0)
                    if debug is True:
                        print(set_num,f_num,img.shape)
    if debug is True:
        print(img_dict.keys())
        for set_num in img_dict.keys():
            print(" ",img_dict[set_num].keys())
            for f_num in img_dict[set_num].keys():
                print("   ",img_dict[set_num][f_num].keys())
    print("====== load img_dict complete ======")
    return img_dict

# %%
img_dict = load_img_dict('F01','F02',debug=True)
# Out:
# ['F01', 'F32', 'F64']
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU =====
# ===== SET01 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET01_F32_10.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_11.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_12.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_13.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_14.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_15.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_16.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_01.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_02.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_03.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_04.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_05.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_06.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_07.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_08.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_09.png
# SET01 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET01_F64_10.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_11.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_12.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_13.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_14.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_15.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_16.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_01.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_02.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_03.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_04.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_05.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_06.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_07.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_08.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_09.png
# SET01 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== SET02 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET02_F32_10.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_11.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_12.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_13.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_14.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_15.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_16.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_01.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_02.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_03.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_04.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_05.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_06.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_07.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_08.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_09.png
# SET02 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET02_F64_10.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_11.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_12.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_13.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_14.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_15.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_16.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_01.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_02.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_03.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_04.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_05.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_06.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_07.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_08.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_09.png
# SET02 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== SET03 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET03_F32_10.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_11.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_12.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_13.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_14.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_15.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_16.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_01.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_02.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_03.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_04.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_05.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_06.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_07.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_08.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_09.png
# SET03 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET03_F64_10.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_11.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_12.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_13.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_14.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_15.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_16.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_01.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_02.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_03.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_04.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_05.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_06.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_07.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_08.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_09.png
# SET03 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== SET04 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET04_F32_10.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_11.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_12.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_13.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_14.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_15.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_16.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_01.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_02.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_03.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_04.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_05.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_06.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_07.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_08.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_09.png
# SET04 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET04_F64_10.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_11.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_12.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_13.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_14.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_15.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_16.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_01.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_02.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_03.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_04.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_05.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_06.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_07.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_08.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_09.png
# SET04 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung+SNU+dataset+221115 =====
# ===== SET10 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET10_F32_01.png
# SET10 F32 (1, 2048, 3072)
# F32  &  SET10_F32_02.png
# SET10 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET10_F64_01.png
# SET10 F64 (1, 2048, 3072)
# F64  &  SET10_F64_02.png
# SET10 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET10_F01_01.png
# SET10 F01 (1, 2048, 3072)
# F01  &  SET10_F01_02.png
# SET10 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET05 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET05_F32_01.png
# SET05 F32 (1, 2048, 3072)
# F32  &  SET05_F32_02.png
# SET05 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET05_F64_01.png
# SET05 F64 (1, 2048, 3072)
# F64  &  SET05_F64_02.png
# SET05 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET05_F01_01.png
# SET05 F01 (1, 2048, 3072)
# F01  &  SET05_F01_02.png
# SET05 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET06 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET06_F32_01.png
# SET06 F32 (1, 2048, 3072)
# F32  &  SET06_F32_02.png
# SET06 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET06_F64_01.png
# SET06 F64 (1, 2048, 3072)
# F64  &  SET06_F64_02.png
# SET06 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET06_F01_01.png
# SET06 F01 (1, 2048, 3072)
# F01  &  SET06_F01_02.png
# SET06 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET07 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET07_F32_01.png
# SET07 F32 (1, 2048, 3072)
# F32  &  SET07_F32_02.png
# SET07 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET07_F64_01.png
# SET07 F64 (1, 2048, 3072)
# F64  &  SET07_F64_02.png
# SET07 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET07_F01_01.png
# SET07 F01 (1, 2048, 3072)
# F01  &  SET07_F01_02.png
# SET07 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET08 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET08_F32_01.png
# SET08 F32 (1, 2048, 3072)
# F32  &  SET08_F32_02.png
# SET08 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET08_F64_01.png
# SET08 F64 (1, 2048, 3072)
# F64  &  SET08_F64_02.png
# SET08 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET08_F01_01.png
# SET08 F01 (1, 2048, 3072)
# F01  &  SET08_F01_02.png
# SET08 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET09 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET09_F32_01.png
# SET09 F32 (1, 2048, 3072)
# F32  &  SET09_F32_02.png
# SET09 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET09_F64_01.png
# SET09 F64 (1, 2048, 3072)
# F64  &  SET09_F64_02.png
# SET09 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET09_F01_01.png
# SET09 F01 (1, 2048, 3072)
# F01  &  SET09_F01_02.png
# SET09 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# dict_keys(['SET01', 'SET02', 'SET03', 'SET04', 'SET10', 'SET05', 'SET06', 'SET07', 'SET08', 'SET09'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET01_F32_10.png', 'SET01_F32_11.png', 'SET01_F32_12.png', 'SET01_F32_13.png', 'SET01_F32_14.png', 'SET01_F32_15.png', 'SET01_F32_16.png', 'SET01_F32_01.png', 'SET01_F32_02.png', 'SET01_F32_03.png', 'SET01_F32_04.png', 'SET01_F32_05.png', 'SET01_F32_06.png', 'SET01_F32_07.png', 'SET01_F32_08.png', 'SET01_F32_09.png'])
#     dict_keys(['SET01_F64_10.png', 'SET01_F64_11.png', 'SET01_F64_12.png', 'SET01_F64_13.png', 'SET01_F64_14.png', 'SET01_F64_15.png', 'SET01_F64_16.png', 'SET01_F64_01.png', 'SET01_F64_02.png', 'SET01_F64_03.png', 'SET01_F64_04.png', 'SET01_F64_05.png', 'SET01_F64_06.png', 'SET01_F64_07.png', 'SET01_F64_08.png', 'SET01_F64_09.png'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET02_F32_10.png', 'SET02_F32_11.png', 'SET02_F32_12.png', 'SET02_F32_13.png', 'SET02_F32_14.png', 'SET02_F32_15.png', 'SET02_F32_16.png', 'SET02_F32_01.png', 'SET02_F32_02.png', 'SET02_F32_03.png', 'SET02_F32_04.png', 'SET02_F32_05.png', 'SET02_F32_06.png', 'SET02_F32_07.png', 'SET02_F32_08.png', 'SET02_F32_09.png'])
#     dict_keys(['SET02_F64_10.png', 'SET02_F64_11.png', 'SET02_F64_12.png', 'SET02_F64_13.png', 'SET02_F64_14.png', 'SET02_F64_15.png', 'SET02_F64_16.png', 'SET02_F64_01.png', 'SET02_F64_02.png', 'SET02_F64_03.png', 'SET02_F64_04.png', 'SET02_F64_05.png', 'SET02_F64_06.png', 'SET02_F64_07.png', 'SET02_F64_08.png', 'SET02_F64_09.png'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET03_F32_10.png', 'SET03_F32_11.png', 'SET03_F32_12.png', 'SET03_F32_13.png', 'SET03_F32_14.png', 'SET03_F32_15.png', 'SET03_F32_16.png', 'SET03_F32_01.png', 'SET03_F32_02.png', 'SET03_F32_03.png', 'SET03_F32_04.png', 'SET03_F32_05.png', 'SET03_F32_06.png', 'SET03_F32_07.png', 'SET03_F32_08.png', 'SET03_F32_09.png'])
#     dict_keys(['SET03_F64_10.png', 'SET03_F64_11.png', 'SET03_F64_12.png', 'SET03_F64_13.png', 'SET03_F64_14.png', 'SET03_F64_15.png', 'SET03_F64_16.png', 'SET03_F64_01.png', 'SET03_F64_02.png', 'SET03_F64_03.png', 'SET03_F64_04.png', 'SET03_F64_05.png', 'SET03_F64_06.png', 'SET03_F64_07.png', 'SET03_F64_08.png', 'SET03_F64_09.png'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET04_F32_10.png', 'SET04_F32_11.png', 'SET04_F32_12.png', 'SET04_F32_13.png', 'SET04_F32_14.png', 'SET04_F32_15.png', 'SET04_F32_16.png', 'SET04_F32_01.png', 'SET04_F32_02.png', 'SET04_F32_03.png', 'SET04_F32_04.png', 'SET04_F32_05.png', 'SET04_F32_06.png', 'SET04_F32_07.png', 'SET04_F32_08.png', 'SET04_F32_09.png'])
#     dict_keys(['SET04_F64_10.png', 'SET04_F64_11.png', 'SET04_F64_12.png', 'SET04_F64_13.png', 'SET04_F64_14.png', 'SET04_F64_15.png', 'SET04_F64_16.png', 'SET04_F64_01.png', 'SET04_F64_02.png', 'SET04_F64_03.png', 'SET04_F64_04.png', 'SET04_F64_05.png', 'SET04_F64_06.png', 'SET04_F64_07.png', 'SET04_F64_08.png', 'SET04_F64_09.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET10_F32_01.png', 'SET10_F32_02.png'])
#     dict_keys(['SET10_F64_01.png', 'SET10_F64_02.png'])
#     dict_keys(['SET10_F01_01.png', 'SET10_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET05_F32_01.png', 'SET05_F32_02.png'])
#     dict_keys(['SET05_F64_01.png', 'SET05_F64_02.png'])
#     dict_keys(['SET05_F01_01.png', 'SET05_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET06_F32_01.png', 'SET06_F32_02.png'])
#     dict_keys(['SET06_F64_01.png', 'SET06_F64_02.png'])
#     dict_keys(['SET06_F01_01.png', 'SET06_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET07_F32_01.png', 'SET07_F32_02.png'])
#     dict_keys(['SET07_F64_01.png', 'SET07_F64_02.png'])
#     dict_keys(['SET07_F01_01.png', 'SET07_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET08_F32_01.png', 'SET08_F32_02.png'])
#     dict_keys(['SET08_F64_01.png', 'SET08_F64_02.png'])
#     dict_keys(['SET08_F01_01.png', 'SET08_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET09_F32_01.png', 'SET09_F32_02.png'])
#     dict_keys(['SET09_F64_01.png', 'SET09_F64_02.png'])
#     dict_keys(['SET09_F01_01.png', 'SET09_F01_02.png'])
# ====== load img_dict complete ======

# %%
plt.imshow(img_dict['SET06']['F01']['SET06_F01_01.png'][0][256:-256,])

# %%
import itertools
def get_fbi_weight(f_num_list = ['F#','F01','F02','F04','F08','F16','F32','F64'],loss = 'MSE_Affine',filter_keyword = ['median']):
    comb = list(itertools.combinations(f_num_list,2))
    total_fbi_weight_list = {}
    for x_f_num,y_f_num in comb:
        fbi_weight_list = glob(f"../weights/230*_FBI_Net*x_as_{x_f_num}*y_as_{y_f_num}*{loss}*")
        for keyword in filter_keyword:
            fbi_weight_list = list(filter(lambda x : keyword not in x,fbi_weight_list))
        total_fbi_weight_list += sorted(list(fbi_weight_list))
        print(x_f_num,y_f_num)
        for fbi_weight in fbi_weight_list:
            print(fbi_weight)
    return total_fbi_weight_list

# %%
gc.collect()
debug= False
partial_check = True
target_fbi_weight = [
    "../weights/230914_FBI_Net_EMSE_Affine_Grayscale_N2N_F01-F01_Samsung_EMSE_Affine_layers_x17_filters_x64_cropsize_256.w",
    
    "../weights/230914_FBI_Net_MSE_Affine_Grayscale_N2N_F01-F01_Samsung_MSE_Affine_layers_x17_filters_x64_cropsize_256.w",
    "../weights/230914_FBI_Net_MSE_Affine_Grayscale_N2N_F01-F02_Samsung_MSE_Affine_layers_x17_filters_x64_cropsize_256.w",
    "../weights/230914_FBI_Net_MSE_Affine_Grayscale_N2N_F01-F04_Samsung_MSE_Affine_layers_x17_filters_x64_cropsize_256.w",
    "../weights/230914_FBI_Net_MSE_Affine_Grayscale_N2N_F01-F08_Samsung_MSE_Affine_layers_x17_filters_x64_cropsize_256.w",
    # "../weights/230920_FBI_Net_MSE_Affine_Grayscale_N2N_F01-F32_Samsung_MSE_Affine_layers_x17_filters_x64_cropsize_256_epoch15.w",
    "../weights/230914_FBI_Net_MSE_Affine_Grayscale_N2N_F01-F32_Samsung_MSE_Affine_layers_x17_filters_x64_cropsize_256.w",
    "../weights/230920_FBI_Net_MSE_Grayscale_N2N_F01-F32_Samsung_MSE_layers_x17_filters_x64_cropsize_256.w",
    "../weights/230914_FBI_Net_N2V_Grayscale_N2N_F01-F01_Samsung_N2V_layers_x17_filters_x64_cropsize_256.w",
    
    "../weights/230914_FBI_Net_MSE_Affine_Grayscale_N2N_F02-F02_Samsung_MSE_Affine_layers_x17_filters_x64_cropsize_256.w",
    "../weights/230914_FBI_Net_MSE_Affine_Grayscale_N2N_F02-F04_Samsung_MSE_Affine_layers_x17_filters_x64_cropsize_256.w",
    "../weights/230914_FBI_Net_MSE_Affine_Grayscale_N2N_F04-F04_Samsung_MSE_Affine_layers_x17_filters_x64_cropsize_256.w",

"../weights/230901_FBI_Net_Grayscale_N2N_F04-F08_Samsung_MSE_Affine_layers_x17_filters_x64_cropsize_256.w",
"../weights/230901_FBI_Net_Grayscale_N2N_F08-F08_Samsung_MSE_Affine_layers_x17_filters_x64_cropsize_256.w",
    # "../weights/230914_NAFNet_light_MSE_Affine_Grayscale_N2N_F01-F01_Samsung_MSE_Affine.w",
    # "../weights/230914_NAFNet_light_MSE_Affine_Grayscale_N2N_F01-F02_Samsung_MSE_Affine.w",
    # "../weights/230914_NAFNet_light_MSE_Affine_Grayscale_N2N_F01-F04_Samsung_MSE_Affine.w",
    # "../weights/230914_NAFNet_light_MSE_Affine_Grayscale_N2N_F01-F08_Samsung_MSE_Affine.w",
    
]

# %%
def parsing_weight_name(fbi_weight_dir):
    target_f = fbi_weight_dir.split("N2N_")[1].split("_Samsung")[0]
    target_x,target_y = target_f.split("-")
    info = "_".join(fbi_weight_dir.split("_")[1:]).split("_Grayscale")[0]
    arch = "_".join(info.split("_")[:2])
    if arch == 'FBI_Net':
        loss_func =  "".join(fbi_weight_dir.split("Samsung_")[1].split("_layers")[0])
    else :
        loss_func = "".join(fbi_weight_dir.split("Samsung_")[1].split(".w")[0])
    return target_x,target_y, arch, loss_func

# %%
for weight_idx,fbi_weight_dir in enumerate(target_fbi_weight):

    target_x,target_y, arch, loss_func = parsing_weight_name(fbi_weight_dir)
    print(target_x,target_y, arch, loss_func)
# Out:
# F01 F01 FBI_Net EMSE_Affine
# F01 F01 FBI_Net MSE_Affine
# F01 F02 FBI_Net MSE_Affine
# F01 F04 FBI_Net MSE_Affine
# F01 F08 FBI_Net MSE_Affine
# F01 F32 FBI_Net MSE_Affine
# F01 F32 FBI_Net MSE
# F01 F01 FBI_Net N2V
# F02 F02 FBI_Net MSE_Affine
# F02 F04 FBI_Net MSE_Affine
# F04 F04 FBI_Net MSE_Affine
# F04 F08 FBI_Net MSE_Affine
# F08 F08 FBI_Net MSE_Affine

# %%
args = get_args(env='colab')
args.pge_weight_dir = None #pge_weight_dir
# args.loss_function = "MSE_Affine"
args.noise_type = 'Poisson-Gaussian'
# args.model_type = 'FBI_Net'
# args.set_num = '1'
args.data_name = 'Samsung'
args.data_type = 'Grayscale'
args.lr = 0.001
args.num_layers = 17
args.num_filters = 64
# args.crop_size = 200
args.debug = False

# %%
from re import T
from core.utils import get_PSNR,get_SSIM


    
debug = False
imshow = False
metric = {}
for weight_idx,fbi_weight_dir in enumerate(target_fbi_weight):

    target_x,target_y, arch, loss_func = parsing_weight_name(fbi_weight_dir)
    if debug is True:
        print(fbi_weight_dir)
        # print(median_filter_input,"median_filter_input")
    # key = f"{target_x}-{target_y}_{dataset_version}"
    key = f"{target_x}-{target_y}_{arch}"
    if loss_func != 'MSE_Affine':
        key += f"_{loss_func}"
    
    model_img_path = f"{folder_name}/{key}"
    os.makedirs(model_img_path,exist_ok=True)
    args.loss_function = loss_func
    args.model_type = arch
    if args.loss_function == 'EMSE_Affine':
        args.pge_weight_dir = "../weights/230914_PGE_Net_Noise_est_Grayscale_N2N_F01-F01_Samsung_Noise_est_cropsize_256_vst_MSE.w"
    else :
        args.pge_weight_dir = None
    print(f"========= {key}  & {loss_func }=========")
    
    model = produce_denoised_img_no_crop(_pge_weight_dir=None,_fbi_weight_dir = fbi_weight_dir,_args = args)
    
    # DENOISE IMAGE
    if target_x == 'F#':
        f_num = 'F01'
    else :
        f_num = target_x
        
    if f_num in ['F08','F16','F32','F64']:
        set_num_list = ['SET01','SET02','SET03','SET04','SET05','SET06','SET07','SET08','SET09','SET10']
    else :
        set_num_list = ['SET05','SET06','SET07','SET08','SET09','SET10'] # ['SET06']#
    if weight_idx == 0:
        metric['median_filter'] = {
            'PSNR' : [],
            'SSIM' : []
        }
        metric['raw'] = {
                'PSNR' : {},
                'SSIM' : {}
            }
        # metric['bm3d'] = {
        #     'PSNR' : [],
        #     'SSIM' : []
        # }
    metric[key] = {'before_PSNR' : {},
            'before_SSIM' : {},
            'PSNR' : {},
            'SSIM' : {}
        }
    print(set_num_list)
    img_dict = load_img_dict(target_x,target_y,debug=True)
    for set_num in img_dict.keys():
        for f_num in [f_num]:
            if f_num in ['F01','F02','F04'] and set_num in ['SET01','SET02','SET03','SET04']:
                continue
            
                # print(f"Since F#, f_num : {f_num} Start")
            print(f"Denoising SET : {set_num}, f_num : {f_num} Start")
            for idx,(filename, img) in enumerate(img_dict[set_num][f_num].items()):
                img = np.expand_dims(img, axis=0) # 1,1536x3074
                F32_img = img_dict[set_num]['F32'][filename.replace(f_num,'F32')][0]
                clean_img = img_dict[set_num]['F64'][filename.replace(f_num,'F64')][0]
                print(filename,set_num,f_num,idx,img.shape)
                denoised_img = model.eval(img)[0][0]
                img = img[0][0]
                metric[key]['PSNR'][filename.split(".")[0]] = get_PSNR(clean_img[256:-256],denoised_img[256:-256])
                metric[key]['SSIM'][filename.split(".")[0]] = get_SSIM(clean_img[256:-256],denoised_img[256:-256])
                
                if os.path.exists(f"{model_img_path}/{filename}") is False:
                    print("imwrite : ",f"{model_img_path}/{filename}")
                    if type(denoised_img) == torch.Tensor:
                        denoised_img = denoised_img.cpu().detach().numpy()
                    cv2.imwrite(f"{model_img_path}/{filename}",denoised_img[0]*255)
                
                if weight_idx == 0:
                    metric['raw']['PSNR'][filename.split(".")[0]] = get_PSNR(clean_img[256:-256],img[256:-256])
                    metric['raw']['SSIM'][filename.split(".")[0]] = get_SSIM(clean_img[256:-256],img[256:-256])
                
                    medianfilterd_img = apply_median_filter_gpu_simple(img)[0][0]
                    median_psnr, median_ssim =  get_PSNR(clean_img[256:-256],medianfilterd_img[256:-256]), get_SSIM(clean_img[256:-256],medianfilterd_img[256:-256])
                    metric['median_filter']['PSNR'].append(median_psnr)
                    metric['median_filter']['SSIM'].append(median_ssim)
                    
                    if set_num == 'SET06' and idx == 0:
                        filename = f"{folder_name}/F32.eps"
                        if os.path.exists(filename) is False:
                            save_eps(F32_img,filename)
                        filename = f"{folder_name}/median_filter_f32.eps"
                        if os.path.exists(filename) is False:
                            save_eps(medianfilterd_img,filename)
                    
            print(f"Denoising SET : {set_num}, f_num : {f_num} End")
    del model
    gc.collect()
# Out:
# ========= F01-F01_FBI_Net_EMSE_Affine  & EMSE_Affine=========
# ['SET05', 'SET06', 'SET07', 'SET08', 'SET09', 'SET10']
# ['F01', 'F32', 'F64']
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU =====
# ===== SET01 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET01_F32_10.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_11.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_12.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_13.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_14.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_15.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_16.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_01.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_02.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_03.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_04.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_05.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_06.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_07.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_08.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_09.png
# SET01 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET01_F64_10.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_11.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_12.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_13.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_14.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_15.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_16.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_01.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_02.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_03.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_04.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_05.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_06.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_07.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_08.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_09.png
# SET01 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== SET02 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET02_F32_10.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_11.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_12.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_13.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_14.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_15.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_16.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_01.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_02.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_03.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_04.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_05.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_06.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_07.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_08.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_09.png
# SET02 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET02_F64_10.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_11.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_12.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_13.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_14.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_15.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_16.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_01.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_02.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_03.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_04.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_05.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_06.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_07.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_08.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_09.png
# SET02 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== SET03 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET03_F32_10.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_11.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_12.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_13.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_14.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_15.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_16.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_01.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_02.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_03.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_04.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_05.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_06.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_07.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_08.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_09.png
# SET03 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET03_F64_10.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_11.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_12.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_13.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_14.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_15.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_16.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_01.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_02.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_03.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_04.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_05.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_06.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_07.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_08.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_09.png
# SET03 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== SET04 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET04_F32_10.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_11.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_12.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_13.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_14.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_15.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_16.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_01.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_02.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_03.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_04.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_05.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_06.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_07.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_08.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_09.png
# SET04 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET04_F64_10.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_11.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_12.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_13.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_14.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_15.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_16.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_01.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_02.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_03.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_04.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_05.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_06.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_07.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_08.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_09.png
# SET04 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung+SNU+dataset+221115 =====
# ===== SET10 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET10_F32_01.png
# SET10 F32 (1, 2048, 3072)
# F32  &  SET10_F32_02.png
# SET10 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET10_F64_01.png
# SET10 F64 (1, 2048, 3072)
# F64  &  SET10_F64_02.png
# SET10 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET10_F01_01.png
# SET10 F01 (1, 2048, 3072)
# F01  &  SET10_F01_02.png
# SET10 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET05 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET05_F32_01.png
# SET05 F32 (1, 2048, 3072)
# F32  &  SET05_F32_02.png
# SET05 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET05_F64_01.png
# SET05 F64 (1, 2048, 3072)
# F64  &  SET05_F64_02.png
# SET05 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET05_F01_01.png
# SET05 F01 (1, 2048, 3072)
# F01  &  SET05_F01_02.png
# SET05 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET06 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET06_F32_01.png
# SET06 F32 (1, 2048, 3072)
# F32  &  SET06_F32_02.png
# SET06 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET06_F64_01.png
# SET06 F64 (1, 2048, 3072)
# F64  &  SET06_F64_02.png
# SET06 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET06_F01_01.png
# SET06 F01 (1, 2048, 3072)
# F01  &  SET06_F01_02.png
# SET06 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET07 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET07_F32_01.png
# SET07 F32 (1, 2048, 3072)
# F32  &  SET07_F32_02.png
# SET07 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET07_F64_01.png
# SET07 F64 (1, 2048, 3072)
# F64  &  SET07_F64_02.png
# SET07 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET07_F01_01.png
# SET07 F01 (1, 2048, 3072)
# F01  &  SET07_F01_02.png
# SET07 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET08 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET08_F32_01.png
# SET08 F32 (1, 2048, 3072)
# F32  &  SET08_F32_02.png
# SET08 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET08_F64_01.png
# SET08 F64 (1, 2048, 3072)
# F64  &  SET08_F64_02.png
# SET08 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET08_F01_01.png
# SET08 F01 (1, 2048, 3072)
# F01  &  SET08_F01_02.png
# SET08 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET09 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET09_F32_01.png
# SET09 F32 (1, 2048, 3072)
# F32  &  SET09_F32_02.png
# SET09 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET09_F64_01.png
# SET09 F64 (1, 2048, 3072)
# F64  &  SET09_F64_02.png
# SET09 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET09_F01_01.png
# SET09 F01 (1, 2048, 3072)
# F01  &  SET09_F01_02.png
# SET09 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# dict_keys(['SET01', 'SET02', 'SET03', 'SET04', 'SET10', 'SET05', 'SET06', 'SET07', 'SET08', 'SET09'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET01_F32_10.png', 'SET01_F32_11.png', 'SET01_F32_12.png', 'SET01_F32_13.png', 'SET01_F32_14.png', 'SET01_F32_15.png', 'SET01_F32_16.png', 'SET01_F32_01.png', 'SET01_F32_02.png', 'SET01_F32_03.png', 'SET01_F32_04.png', 'SET01_F32_05.png', 'SET01_F32_06.png', 'SET01_F32_07.png', 'SET01_F32_08.png', 'SET01_F32_09.png'])
#     dict_keys(['SET01_F64_10.png', 'SET01_F64_11.png', 'SET01_F64_12.png', 'SET01_F64_13.png', 'SET01_F64_14.png', 'SET01_F64_15.png', 'SET01_F64_16.png', 'SET01_F64_01.png', 'SET01_F64_02.png', 'SET01_F64_03.png', 'SET01_F64_04.png', 'SET01_F64_05.png', 'SET01_F64_06.png', 'SET01_F64_07.png', 'SET01_F64_08.png', 'SET01_F64_09.png'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET02_F32_10.png', 'SET02_F32_11.png', 'SET02_F32_12.png', 'SET02_F32_13.png', 'SET02_F32_14.png', 'SET02_F32_15.png', 'SET02_F32_16.png', 'SET02_F32_01.png', 'SET02_F32_02.png', 'SET02_F32_03.png', 'SET02_F32_04.png', 'SET02_F32_05.png', 'SET02_F32_06.png', 'SET02_F32_07.png', 'SET02_F32_08.png', 'SET02_F32_09.png'])
#     dict_keys(['SET02_F64_10.png', 'SET02_F64_11.png', 'SET02_F64_12.png', 'SET02_F64_13.png', 'SET02_F64_14.png', 'SET02_F64_15.png', 'SET02_F64_16.png', 'SET02_F64_01.png', 'SET02_F64_02.png', 'SET02_F64_03.png', 'SET02_F64_04.png', 'SET02_F64_05.png', 'SET02_F64_06.png', 'SET02_F64_07.png', 'SET02_F64_08.png', 'SET02_F64_09.png'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET03_F32_10.png', 'SET03_F32_11.png', 'SET03_F32_12.png', 'SET03_F32_13.png', 'SET03_F32_14.png', 'SET03_F32_15.png', 'SET03_F32_16.png', 'SET03_F32_01.png', 'SET03_F32_02.png', 'SET03_F32_03.png', 'SET03_F32_04.png', 'SET03_F32_05.png', 'SET03_F32_06.png', 'SET03_F32_07.png', 'SET03_F32_08.png', 'SET03_F32_09.png'])
#     dict_keys(['SET03_F64_10.png', 'SET03_F64_11.png', 'SET03_F64_12.png', 'SET03_F64_13.png', 'SET03_F64_14.png', 'SET03_F64_15.png', 'SET03_F64_16.png', 'SET03_F64_01.png', 'SET03_F64_02.png', 'SET03_F64_03.png', 'SET03_F64_04.png', 'SET03_F64_05.png', 'SET03_F64_06.png', 'SET03_F64_07.png', 'SET03_F64_08.png', 'SET03_F64_09.png'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET04_F32_10.png', 'SET04_F32_11.png', 'SET04_F32_12.png', 'SET04_F32_13.png', 'SET04_F32_14.png', 'SET04_F32_15.png', 'SET04_F32_16.png', 'SET04_F32_01.png', 'SET04_F32_02.png', 'SET04_F32_03.png', 'SET04_F32_04.png', 'SET04_F32_05.png', 'SET04_F32_06.png', 'SET04_F32_07.png', 'SET04_F32_08.png', 'SET04_F32_09.png'])
#     dict_keys(['SET04_F64_10.png', 'SET04_F64_11.png', 'SET04_F64_12.png', 'SET04_F64_13.png', 'SET04_F64_14.png', 'SET04_F64_15.png', 'SET04_F64_16.png', 'SET04_F64_01.png', 'SET04_F64_02.png', 'SET04_F64_03.png', 'SET04_F64_04.png', 'SET04_F64_05.png', 'SET04_F64_06.png', 'SET04_F64_07.png', 'SET04_F64_08.png', 'SET04_F64_09.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET10_F32_01.png', 'SET10_F32_02.png'])
#     dict_keys(['SET10_F64_01.png', 'SET10_F64_02.png'])
#     dict_keys(['SET10_F01_01.png', 'SET10_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET05_F32_01.png', 'SET05_F32_02.png'])
#     dict_keys(['SET05_F64_01.png', 'SET05_F64_02.png'])
#     dict_keys(['SET05_F01_01.png', 'SET05_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET06_F32_01.png', 'SET06_F32_02.png'])
#     dict_keys(['SET06_F64_01.png', 'SET06_F64_02.png'])
#     dict_keys(['SET06_F01_01.png', 'SET06_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET07_F32_01.png', 'SET07_F32_02.png'])
#     dict_keys(['SET07_F64_01.png', 'SET07_F64_02.png'])
#     dict_keys(['SET07_F01_01.png', 'SET07_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET08_F32_01.png', 'SET08_F32_02.png'])
#     dict_keys(['SET08_F64_01.png', 'SET08_F64_02.png'])
#     dict_keys(['SET08_F01_01.png', 'SET08_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET09_F32_01.png', 'SET09_F32_02.png'])
#     dict_keys(['SET09_F64_01.png', 'SET09_F64_02.png'])
#     dict_keys(['SET09_F01_01.png', 'SET09_F01_02.png'])
# ====== load img_dict complete ======
# Denoising SET : SET10, f_num : F01 Start
# SET10_F01_01.png SET10 F01 0 (1, 1, 2048, 3072)
# SET10_F01_02.png SET10 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET10, f_num : F01 End
# Denoising SET : SET05, f_num : F01 Start
# SET05_F01_01.png SET05 F01 0 (1, 1, 2048, 3072)
# SET05_F01_02.png SET05 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET05, f_num : F01 End
# Denoising SET : SET06, f_num : F01 Start
# SET06_F01_01.png SET06 F01 0 (1, 1, 2048, 3072)
# SET06_F01_02.png SET06 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET06, f_num : F01 End
# Denoising SET : SET07, f_num : F01 Start
# SET07_F01_01.png SET07 F01 0 (1, 1, 2048, 3072)
# SET07_F01_02.png SET07 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET07, f_num : F01 End
# Denoising SET : SET08, f_num : F01 Start
# SET08_F01_01.png SET08 F01 0 (1, 1, 2048, 3072)
# SET08_F01_02.png SET08 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET08, f_num : F01 End
# Denoising SET : SET09, f_num : F01 Start
# SET09_F01_01.png SET09 F01 0 (1, 1, 2048, 3072)
# SET09_F01_02.png SET09 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET09, f_num : F01 End
# ========= F01-F01_FBI_Net  & MSE_Affine=========
# ['SET05', 'SET06', 'SET07', 'SET08', 'SET09', 'SET10']
# ['F01', 'F32', 'F64']
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU =====
# ===== SET01 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET01_F32_10.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_11.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_12.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_13.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_14.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_15.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_16.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_01.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_02.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_03.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_04.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_05.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_06.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_07.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_08.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_09.png
# SET01 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET01_F64_10.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_11.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_12.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_13.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_14.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_15.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_16.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_01.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_02.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_03.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_04.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_05.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_06.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_07.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_08.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_09.png
# SET01 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== SET02 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET02_F32_10.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_11.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_12.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_13.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_14.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_15.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_16.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_01.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_02.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_03.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_04.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_05.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_06.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_07.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_08.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_09.png
# SET02 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET02_F64_10.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_11.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_12.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_13.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_14.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_15.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_16.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_01.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_02.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_03.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_04.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_05.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_06.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_07.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_08.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_09.png
# SET02 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== SET03 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET03_F32_10.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_11.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_12.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_13.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_14.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_15.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_16.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_01.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_02.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_03.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_04.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_05.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_06.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_07.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_08.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_09.png
# SET03 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET03_F64_10.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_11.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_12.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_13.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_14.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_15.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_16.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_01.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_02.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_03.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_04.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_05.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_06.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_07.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_08.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_09.png
# SET03 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== SET04 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET04_F32_10.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_11.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_12.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_13.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_14.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_15.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_16.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_01.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_02.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_03.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_04.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_05.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_06.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_07.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_08.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_09.png
# SET04 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET04_F64_10.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_11.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_12.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_13.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_14.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_15.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_16.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_01.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_02.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_03.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_04.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_05.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_06.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_07.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_08.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_09.png
# SET04 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung+SNU+dataset+221115 =====
# ===== SET10 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET10_F32_01.png
# SET10 F32 (1, 2048, 3072)
# F32  &  SET10_F32_02.png
# SET10 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET10_F64_01.png
# SET10 F64 (1, 2048, 3072)
# F64  &  SET10_F64_02.png
# SET10 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET10_F01_01.png
# SET10 F01 (1, 2048, 3072)
# F01  &  SET10_F01_02.png
# SET10 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET05 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET05_F32_01.png
# SET05 F32 (1, 2048, 3072)
# F32  &  SET05_F32_02.png
# SET05 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET05_F64_01.png
# SET05 F64 (1, 2048, 3072)
# F64  &  SET05_F64_02.png
# SET05 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET05_F01_01.png
# SET05 F01 (1, 2048, 3072)
# F01  &  SET05_F01_02.png
# SET05 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET06 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET06_F32_01.png
# SET06 F32 (1, 2048, 3072)
# F32  &  SET06_F32_02.png
# SET06 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET06_F64_01.png
# SET06 F64 (1, 2048, 3072)
# F64  &  SET06_F64_02.png
# SET06 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET06_F01_01.png
# SET06 F01 (1, 2048, 3072)
# F01  &  SET06_F01_02.png
# SET06 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET07 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET07_F32_01.png
# SET07 F32 (1, 2048, 3072)
# F32  &  SET07_F32_02.png
# SET07 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET07_F64_01.png
# SET07 F64 (1, 2048, 3072)
# F64  &  SET07_F64_02.png
# SET07 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET07_F01_01.png
# SET07 F01 (1, 2048, 3072)
# F01  &  SET07_F01_02.png
# SET07 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET08 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET08_F32_01.png
# SET08 F32 (1, 2048, 3072)
# F32  &  SET08_F32_02.png
# SET08 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET08_F64_01.png
# SET08 F64 (1, 2048, 3072)
# F64  &  SET08_F64_02.png
# SET08 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET08_F01_01.png
# SET08 F01 (1, 2048, 3072)
# F01  &  SET08_F01_02.png
# SET08 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET09 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET09_F32_01.png
# SET09 F32 (1, 2048, 3072)
# F32  &  SET09_F32_02.png
# SET09 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET09_F64_01.png
# SET09 F64 (1, 2048, 3072)
# F64  &  SET09_F64_02.png
# SET09 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET09_F01_01.png
# SET09 F01 (1, 2048, 3072)
# F01  &  SET09_F01_02.png
# SET09 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# dict_keys(['SET01', 'SET02', 'SET03', 'SET04', 'SET10', 'SET05', 'SET06', 'SET07', 'SET08', 'SET09'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET01_F32_10.png', 'SET01_F32_11.png', 'SET01_F32_12.png', 'SET01_F32_13.png', 'SET01_F32_14.png', 'SET01_F32_15.png', 'SET01_F32_16.png', 'SET01_F32_01.png', 'SET01_F32_02.png', 'SET01_F32_03.png', 'SET01_F32_04.png', 'SET01_F32_05.png', 'SET01_F32_06.png', 'SET01_F32_07.png', 'SET01_F32_08.png', 'SET01_F32_09.png'])
#     dict_keys(['SET01_F64_10.png', 'SET01_F64_11.png', 'SET01_F64_12.png', 'SET01_F64_13.png', 'SET01_F64_14.png', 'SET01_F64_15.png', 'SET01_F64_16.png', 'SET01_F64_01.png', 'SET01_F64_02.png', 'SET01_F64_03.png', 'SET01_F64_04.png', 'SET01_F64_05.png', 'SET01_F64_06.png', 'SET01_F64_07.png', 'SET01_F64_08.png', 'SET01_F64_09.png'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET02_F32_10.png', 'SET02_F32_11.png', 'SET02_F32_12.png', 'SET02_F32_13.png', 'SET02_F32_14.png', 'SET02_F32_15.png', 'SET02_F32_16.png', 'SET02_F32_01.png', 'SET02_F32_02.png', 'SET02_F32_03.png', 'SET02_F32_04.png', 'SET02_F32_05.png', 'SET02_F32_06.png', 'SET02_F32_07.png', 'SET02_F32_08.png', 'SET02_F32_09.png'])
#     dict_keys(['SET02_F64_10.png', 'SET02_F64_11.png', 'SET02_F64_12.png', 'SET02_F64_13.png', 'SET02_F64_14.png', 'SET02_F64_15.png', 'SET02_F64_16.png', 'SET02_F64_01.png', 'SET02_F64_02.png', 'SET02_F64_03.png', 'SET02_F64_04.png', 'SET02_F64_05.png', 'SET02_F64_06.png', 'SET02_F64_07.png', 'SET02_F64_08.png', 'SET02_F64_09.png'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET03_F32_10.png', 'SET03_F32_11.png', 'SET03_F32_12.png', 'SET03_F32_13.png', 'SET03_F32_14.png', 'SET03_F32_15.png', 'SET03_F32_16.png', 'SET03_F32_01.png', 'SET03_F32_02.png', 'SET03_F32_03.png', 'SET03_F32_04.png', 'SET03_F32_05.png', 'SET03_F32_06.png', 'SET03_F32_07.png', 'SET03_F32_08.png', 'SET03_F32_09.png'])
#     dict_keys(['SET03_F64_10.png', 'SET03_F64_11.png', 'SET03_F64_12.png', 'SET03_F64_13.png', 'SET03_F64_14.png', 'SET03_F64_15.png', 'SET03_F64_16.png', 'SET03_F64_01.png', 'SET03_F64_02.png', 'SET03_F64_03.png', 'SET03_F64_04.png', 'SET03_F64_05.png', 'SET03_F64_06.png', 'SET03_F64_07.png', 'SET03_F64_08.png', 'SET03_F64_09.png'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET04_F32_10.png', 'SET04_F32_11.png', 'SET04_F32_12.png', 'SET04_F32_13.png', 'SET04_F32_14.png', 'SET04_F32_15.png', 'SET04_F32_16.png', 'SET04_F32_01.png', 'SET04_F32_02.png', 'SET04_F32_03.png', 'SET04_F32_04.png', 'SET04_F32_05.png', 'SET04_F32_06.png', 'SET04_F32_07.png', 'SET04_F32_08.png', 'SET04_F32_09.png'])
#     dict_keys(['SET04_F64_10.png', 'SET04_F64_11.png', 'SET04_F64_12.png', 'SET04_F64_13.png', 'SET04_F64_14.png', 'SET04_F64_15.png', 'SET04_F64_16.png', 'SET04_F64_01.png', 'SET04_F64_02.png', 'SET04_F64_03.png', 'SET04_F64_04.png', 'SET04_F64_05.png', 'SET04_F64_06.png', 'SET04_F64_07.png', 'SET04_F64_08.png', 'SET04_F64_09.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET10_F32_01.png', 'SET10_F32_02.png'])
#     dict_keys(['SET10_F64_01.png', 'SET10_F64_02.png'])
#     dict_keys(['SET10_F01_01.png', 'SET10_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET05_F32_01.png', 'SET05_F32_02.png'])
#     dict_keys(['SET05_F64_01.png', 'SET05_F64_02.png'])
#     dict_keys(['SET05_F01_01.png', 'SET05_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET06_F32_01.png', 'SET06_F32_02.png'])
#     dict_keys(['SET06_F64_01.png', 'SET06_F64_02.png'])
#     dict_keys(['SET06_F01_01.png', 'SET06_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET07_F32_01.png', 'SET07_F32_02.png'])
#     dict_keys(['SET07_F64_01.png', 'SET07_F64_02.png'])
#     dict_keys(['SET07_F01_01.png', 'SET07_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET08_F32_01.png', 'SET08_F32_02.png'])
#     dict_keys(['SET08_F64_01.png', 'SET08_F64_02.png'])
#     dict_keys(['SET08_F01_01.png', 'SET08_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET09_F32_01.png', 'SET09_F32_02.png'])
#     dict_keys(['SET09_F64_01.png', 'SET09_F64_02.png'])
#     dict_keys(['SET09_F01_01.png', 'SET09_F01_02.png'])
# ====== load img_dict complete ======
# Denoising SET : SET10, f_num : F01 Start
# SET10_F01_01.png SET10 F01 0 (1, 1, 2048, 3072)
# SET10_F01_02.png SET10 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET10, f_num : F01 End
# Denoising SET : SET05, f_num : F01 Start
# SET05_F01_01.png SET05 F01 0 (1, 1, 2048, 3072)
# SET05_F01_02.png SET05 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET05, f_num : F01 End
# Denoising SET : SET06, f_num : F01 Start
# SET06_F01_01.png SET06 F01 0 (1, 1, 2048, 3072)
# SET06_F01_02.png SET06 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET06, f_num : F01 End
# Denoising SET : SET07, f_num : F01 Start
# SET07_F01_01.png SET07 F01 0 (1, 1, 2048, 3072)
# SET07_F01_02.png SET07 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET07, f_num : F01 End
# Denoising SET : SET08, f_num : F01 Start
# SET08_F01_01.png SET08 F01 0 (1, 1, 2048, 3072)
# SET08_F01_02.png SET08 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET08, f_num : F01 End
# Denoising SET : SET09, f_num : F01 Start
# SET09_F01_01.png SET09 F01 0 (1, 1, 2048, 3072)
# SET09_F01_02.png SET09 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET09, f_num : F01 End
# ========= F01-F02_FBI_Net  & MSE_Affine=========
# ['SET05', 'SET06', 'SET07', 'SET08', 'SET09', 'SET10']
# ['F01', 'F32', 'F64']
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU =====
# ===== SET01 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET01_F32_10.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_11.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_12.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_13.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_14.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_15.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_16.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_01.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_02.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_03.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_04.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_05.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_06.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_07.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_08.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_09.png
# SET01 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET01_F64_10.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_11.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_12.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_13.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_14.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_15.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_16.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_01.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_02.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_03.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_04.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_05.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_06.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_07.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_08.png
# SET01 F64 (1, 2048, 3072)
# F64  &  SET01_F64_09.png
# SET01 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== SET02 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET02_F32_10.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_11.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_12.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_13.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_14.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_15.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_16.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_01.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_02.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_03.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_04.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_05.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_06.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_07.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_08.png
# SET02 F32 (1, 2048, 3072)
# F32  &  SET02_F32_09.png
# SET02 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET02_F64_10.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_11.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_12.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_13.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_14.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_15.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_16.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_01.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_02.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_03.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_04.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_05.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_06.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_07.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_08.png
# SET02 F64 (1, 2048, 3072)
# F64  &  SET02_F64_09.png
# SET02 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== SET03 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET03_F32_10.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_11.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_12.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_13.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_14.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_15.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_16.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_01.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_02.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_03.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_04.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_05.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_06.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_07.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_08.png
# SET03 F32 (1, 2048, 3072)
# F32  &  SET03_F32_09.png
# SET03 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET03_F64_10.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_11.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_12.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_13.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_14.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_15.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_16.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_01.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_02.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_03.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_04.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_05.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_06.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_07.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_08.png
# SET03 F64 (1, 2048, 3072)
# F64  &  SET03_F64_09.png
# SET03 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== SET04 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET04_F32_10.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_11.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_12.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_13.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_14.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_15.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_16.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_01.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_02.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_03.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_04.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_05.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_06.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_07.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_08.png
# SET04 F32 (1, 2048, 3072)
# F32  &  SET04_F32_09.png
# SET04 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET04_F64_10.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_11.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_12.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_13.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_14.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_15.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_16.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_01.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_02.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_03.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_04.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_05.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_06.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_07.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_08.png
# SET04 F64 (1, 2048, 3072)
# F64  &  SET04_F64_09.png
# SET04 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung+SNU+dataset+221115 =====
# ===== SET10 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET10_F32_01.png
# SET10 F32 (1, 2048, 3072)
# F32  &  SET10_F32_02.png
# SET10 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET10_F64_01.png
# SET10 F64 (1, 2048, 3072)
# F64  &  SET10_F64_02.png
# SET10 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET10_F01_01.png
# SET10 F01 (1, 2048, 3072)
# F01  &  SET10_F01_02.png
# SET10 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET05 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET05_F32_01.png
# SET05 F32 (1, 2048, 3072)
# F32  &  SET05_F32_02.png
# SET05 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET05_F64_01.png
# SET05 F64 (1, 2048, 3072)
# F64  &  SET05_F64_02.png
# SET05 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET05_F01_01.png
# SET05 F01 (1, 2048, 3072)
# F01  &  SET05_F01_02.png
# SET05 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET06 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET06_F32_01.png
# SET06 F32 (1, 2048, 3072)
# F32  &  SET06_F32_02.png
# SET06 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET06_F64_01.png
# SET06 F64 (1, 2048, 3072)
# F64  &  SET06_F64_02.png
# SET06 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET06_F01_01.png
# SET06 F01 (1, 2048, 3072)
# F01  &  SET06_F01_02.png
# SET06 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET07 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET07_F32_01.png
# SET07 F32 (1, 2048, 3072)
# F32  &  SET07_F32_02.png
# SET07 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET07_F64_01.png
# SET07 F64 (1, 2048, 3072)
# F64  &  SET07_F64_02.png
# SET07 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET07_F01_01.png
# SET07 F01 (1, 2048, 3072)
# F01  &  SET07_F01_02.png
# SET07 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET08 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET08_F32_01.png
# SET08 F32 (1, 2048, 3072)
# F32  &  SET08_F32_02.png
# SET08 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET08_F64_01.png
# SET08 F64 (1, 2048, 3072)
# F64  &  SET08_F64_02.png
# SET08 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET08_F01_01.png
# SET08 F01 (1, 2048, 3072)
# F01  &  SET08_F01_02.png
# SET08 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# ===== SET09 =====
# ['F4', 'F32', 'F8', 'F64', 'F16', 'F1', 'F2']
# F04  is not in  ['F01', 'F32', 'F64']
# F32  &  SET09_F32_01.png
# SET09 F32 (1, 2048, 3072)
# F32  &  SET09_F32_02.png
# SET09 F32 (1, 2048, 3072)
# F08  is not in  ['F01', 'F32', 'F64']
# F64  &  SET09_F64_01.png
# SET09 F64 (1, 2048, 3072)
# F64  &  SET09_F64_02.png
# SET09 F64 (1, 2048, 3072)
# F16  is not in  ['F01', 'F32', 'F64']
# F01  &  SET09_F01_01.png
# SET09 F01 (1, 2048, 3072)
# F01  &  SET09_F01_02.png
# SET09 F01 (1, 2048, 3072)
# F02  is not in  ['F01', 'F32', 'F64']
# dict_keys(['SET01', 'SET02', 'SET03', 'SET04', 'SET10', 'SET05', 'SET06', 'SET07', 'SET08', 'SET09'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET01_F32_10.png', 'SET01_F32_11.png', 'SET01_F32_12.png', 'SET01_F32_13.png', 'SET01_F32_14.png', 'SET01_F32_15.png', 'SET01_F32_16.png', 'SET01_F32_01.png', 'SET01_F32_02.png', 'SET01_F32_03.png', 'SET01_F32_04.png', 'SET01_F32_05.png', 'SET01_F32_06.png', 'SET01_F32_07.png', 'SET01_F32_08.png', 'SET01_F32_09.png'])
#     dict_keys(['SET01_F64_10.png', 'SET01_F64_11.png', 'SET01_F64_12.png', 'SET01_F64_13.png', 'SET01_F64_14.png', 'SET01_F64_15.png', 'SET01_F64_16.png', 'SET01_F64_01.png', 'SET01_F64_02.png', 'SET01_F64_03.png', 'SET01_F64_04.png', 'SET01_F64_05.png', 'SET01_F64_06.png', 'SET01_F64_07.png', 'SET01_F64_08.png', 'SET01_F64_09.png'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET02_F32_10.png', 'SET02_F32_11.png', 'SET02_F32_12.png', 'SET02_F32_13.png', 'SET02_F32_14.png', 'SET02_F32_15.png', 'SET02_F32_16.png', 'SET02_F32_01.png', 'SET02_F32_02.png', 'SET02_F32_03.png', 'SET02_F32_04.png', 'SET02_F32_05.png', 'SET02_F32_06.png', 'SET02_F32_07.png', 'SET02_F32_08.png', 'SET02_F32_09.png'])
#     dict_keys(['SET02_F64_10.png', 'SET02_F64_11.png', 'SET02_F64_12.png', 'SET02_F64_13.png', 'SET02_F64_14.png', 'SET02_F64_15.png', 'SET02_F64_16.png', 'SET02_F64_01.png', 'SET02_F64_02.png', 'SET02_F64_03.png', 'SET02_F64_04.png', 'SET02_F64_05.png', 'SET02_F64_06.png', 'SET02_F64_07.png', 'SET02_F64_08.png', 'SET02_F64_09.png'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET03_F32_10.png', 'SET03_F32_11.png', 'SET03_F32_12.png', 'SET03_F32_13.png', 'SET03_F32_14.png', 'SET03_F32_15.png', 'SET03_F32_16.png', 'SET03_F32_01.png', 'SET03_F32_02.png', 'SET03_F32_03.png', 'SET03_F32_04.png', 'SET03_F32_05.png', 'SET03_F32_06.png', 'SET03_F32_07.png', 'SET03_F32_08.png', 'SET03_F32_09.png'])
#     dict_keys(['SET03_F64_10.png', 'SET03_F64_11.png', 'SET03_F64_12.png', 'SET03_F64_13.png', 'SET03_F64_14.png', 'SET03_F64_15.png', 'SET03_F64_16.png', 'SET03_F64_01.png', 'SET03_F64_02.png', 'SET03_F64_03.png', 'SET03_F64_04.png', 'SET03_F64_05.png', 'SET03_F64_06.png', 'SET03_F64_07.png', 'SET03_F64_08.png', 'SET03_F64_09.png'])
#   dict_keys(['F32', 'F64'])
#     dict_keys(['SET04_F32_10.png', 'SET04_F32_11.png', 'SET04_F32_12.png', 'SET04_F32_13.png', 'SET04_F32_14.png', 'SET04_F32_15.png', 'SET04_F32_16.png', 'SET04_F32_01.png', 'SET04_F32_02.png', 'SET04_F32_03.png', 'SET04_F32_04.png', 'SET04_F32_05.png', 'SET04_F32_06.png', 'SET04_F32_07.png', 'SET04_F32_08.png', 'SET04_F32_09.png'])
#     dict_keys(['SET04_F64_10.png', 'SET04_F64_11.png', 'SET04_F64_12.png', 'SET04_F64_13.png', 'SET04_F64_14.png', 'SET04_F64_15.png', 'SET04_F64_16.png', 'SET04_F64_01.png', 'SET04_F64_02.png', 'SET04_F64_03.png', 'SET04_F64_04.png', 'SET04_F64_05.png', 'SET04_F64_06.png', 'SET04_F64_07.png', 'SET04_F64_08.png', 'SET04_F64_09.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET10_F32_01.png', 'SET10_F32_02.png'])
#     dict_keys(['SET10_F64_01.png', 'SET10_F64_02.png'])
#     dict_keys(['SET10_F01_01.png', 'SET10_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET05_F32_01.png', 'SET05_F32_02.png'])
#     dict_keys(['SET05_F64_01.png', 'SET05_F64_02.png'])
#     dict_keys(['SET05_F01_01.png', 'SET05_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET06_F32_01.png', 'SET06_F32_02.png'])
#     dict_keys(['SET06_F64_01.png', 'SET06_F64_02.png'])
#     dict_keys(['SET06_F01_01.png', 'SET06_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET07_F32_01.png', 'SET07_F32_02.png'])
#     dict_keys(['SET07_F64_01.png', 'SET07_F64_02.png'])
#     dict_keys(['SET07_F01_01.png', 'SET07_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET08_F32_01.png', 'SET08_F32_02.png'])
#     dict_keys(['SET08_F64_01.png', 'SET08_F64_02.png'])
#     dict_keys(['SET08_F01_01.png', 'SET08_F01_02.png'])
#   dict_keys(['F32', 'F64', 'F01'])
#     dict_keys(['SET09_F32_01.png', 'SET09_F32_02.png'])
#     dict_keys(['SET09_F64_01.png', 'SET09_F64_02.png'])
#     dict_keys(['SET09_F01_01.png', 'SET09_F01_02.png'])
# ====== load img_dict complete ======
# Denoising SET : SET10, f_num : F01 Start
# SET10_F01_01.png SET10 F01 0 (1, 1, 2048, 3072)
# SET10_F01_02.png SET10 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET10, f_num : F01 End
# Denoising SET : SET05, f_num : F01 Start
# SET05_F01_01.png SET05 F01 0 (1, 1, 2048, 3072)
# SET05_F01_02.png SET05 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET05, f_num : F01 End
# Denoising SET : SET06, f_num : F01 Start
# SET06_F01_01.png SET06 F01 0 (1, 1, 2048, 3072)
# SET06_F01_02.png SET06 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET06, f_num : F01 End
# Denoising SET : SET07, f_num : F01 Start
# SET07_F01_01.png SET07 F01 0 (1, 1, 2048, 3072)
# SET07_F01_02.png SET07 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET07, f_num : F01 End
# Denoising SET : SET08, f_num : F01 Start
# SET08_F01_01.png SET08 F01 0 (1, 1, 2048, 3072)
# SET08_F01_02.png SET08 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET08, f_num : F01 End
# Denoising SET : SET09, f_num : F01 Start
# SET09_F01_01.png SET09 F01 0 (1, 1, 2048, 3072)
# SET09_F01_02.png SET09 F01 1 (1, 1, 2048, 3072)
# Denoising SET : SET09, f_num : F01 End
# ========= F01-F04_FBI_Net  & MSE_Affine=========
# ['SET05', 'SET06', 'SET07', 'SET08', 'SET09', 'SET10']
# ['F01', 'F32', 'F64']
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU =====
# ===== SET01 =====
# ['F32', 'F8', 'F64', 'F16']
# F32  &  SET01_F32_10.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_11.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_12.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_13.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_14.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_15.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_16.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_01.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_02.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_03.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_04.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_05.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_06.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_07.png
# SET01 F32 (1, 2048, 3072)
# F32  &  SET01_F32_08.png
# ...
#   dict_keys(['F32', 'F08', 'F64'])
#     dict_keys(['SET02_F32_10.png', 'SET02_F32_11.png', 'SET02_F32_12.png', 'SET02_F32_13.png', 'SET02_F32_14.png', 'SET02_F32_15.png', 'SET02_F32_16.png', 'SET02_F32_01.png', 'SET02_F32_02.png', 'SET02_F32_03.png', 'SET02_F32_04.png', 'SET02_F32_05.png', 'SET02_F32_06.png', 'SET02_F32_07.png', 'SET02_F32_08.png', 'SET02_F32_09.png'])
#     dict_keys(['SET02_F08_10.png', 'SET02_F08_11.png', 'SET02_F08_12.png', 'SET02_F08_13.png', 'SET02_F08_14.png', 'SET02_F08_15.png', 'SET02_F08_16.png', 'SET02_F08_01.png', 'SET02_F08_02.png', 'SET02_F08_03.png', 'SET02_F08_04.png', 'SET02_F08_05.png', 'SET02_F08_06.png', 'SET02_F08_07.png', 'SET02_F08_08.png', 'SET02_F08_09.png'])
#     dict_keys(['SET02_F64_10.png', 'SET02_F64_11.png', 'SET02_F64_12.png', 'SET02_F64_13.png', 'SET02_F64_14.png', 'SET02_F64_15.png', 'SET02_F64_16.png', 'SET02_F64_01.png', 'SET02_F64_02.png', 'SET02_F64_03.png', 'SET02_F64_04.png', 'SET02_F64_05.png', 'SET02_F64_06.png', 'SET02_F64_07.png', 'SET02_F64_08.png', 'SET02_F64_09.png'])
#   dict_keys(['F32', 'F08', 'F64'])
#     dict_keys(['SET03_F32_10.png', 'SET03_F32_11.png', 'SET03_F32_12.png', 'SET03_F32_13.png', 'SET03_F32_14.png', 'SET03_F32_15.png', 'SET03_F32_16.png', 'SET03_F32_01.png', 'SET03_F32_02.png', 'SET03_F32_03.png', 'SET03_F32_04.png', 'SET03_F32_05.png', 'SET03_F32_06.png', 'SET03_F32_07.png', 'SET03_F32_08.png', 'SET03_F32_09.png'])
#     dict_keys(['SET03_F08_10.png', 'SET03_F08_11.png', 'SET03_F08_12.png', 'SET03_F08_13.png', 'SET03_F08_14.png', 'SET03_F08_15.png', 'SET03_F08_16.png', 'SET03_F08_01.png', 'SET03_F08_02.png', 'SET03_F08_03.png', 'SET03_F08_04.png', 'SET03_F08_05.png', 'SET03_F08_06.png', 'SET03_F08_07.png', 'SET03_F08_08.png', 'SET03_F08_09.png'])
#     dict_keys(['SET03_F64_10.png', 'SET03_F64_11.png', 'SET03_F64_12.png', 'SET03_F64_13.png', 'SET03_F64_14.png', 'SET03_F64_15.png', 'SET03_F64_16.png', 'SET03_F64_01.png', 'SET03_F64_02.png', 'SET03_F64_03.png', 'SET03_F64_04.png', 'SET03_F64_05.png', 'SET03_F64_06.png', 'SET03_F64_07.png', 'SET03_F64_08.png', 'SET03_F64_09.png'])
#   dict_keys(['F32', 'F08', 'F64'])
#     dict_keys(['SET04_F32_10.png', 'SET04_F32_11.png', 'SET04_F32_12.png', 'SET04_F32_13.png', 'SET04_F32_14.png', 'SET04_F32_15.png', 'SET04_F32_16.png', 'SET04_F32_01.png', 'SET04_F32_02.png', 'SET04_F32_03.png', 'SET04_F32_04.png', 'SET04_F32_05.png', 'SET04_F32_06.png', 'SET04_F32_07.png', 'SET04_F32_08.png', 'SET04_F32_09.png'])
#     dict_keys(['SET04_F08_10.png', 'SET04_F08_11.png', 'SET04_F08_12.png', 'SET04_F08_13.png', 'SET04_F08_14.png', 'SET04_F08_15.png', 'SET04_F08_16.png', 'SET04_F08_01.png', 'SET04_F08_02.png', 'SET04_F08_03.png', 'SET04_F08_04.png', 'SET04_F08_05.png', 'SET04_F08_06.png', 'SET04_F08_07.png', 'SET04_F08_08.png', 'SET04_F08_09.png'])
#     dict_keys(['SET04_F64_10.png', 'SET04_F64_11.png', 'SET04_F64_12.png', 'SET04_F64_13.png', 'SET04_F64_14.png', 'SET04_F64_15.png', 'SET04_F64_16.png', 'SET04_F64_01.png', 'SET04_F64_02.png', 'SET04_F64_03.png', 'SET04_F64_04.png', 'SET04_F64_05.png', 'SET04_F64_06.png', 'SET04_F64_07.png', 'SET04_F64_08.png', 'SET04_F64_09.png'])
#   dict_keys(['F32', 'F08', 'F64'])
#     dict_keys(['SET10_F32_01.png', 'SET10_F32_02.png'])
#     dict_keys(['SET10_F08_01.png', 'SET10_F08_02.png'])
#     dict_keys(['SET10_F64_01.png', 'SET10_F64_02.png'])
#   dict_keys(['F32', 'F08', 'F64'])
#     dict_keys(['SET05_F32_01.png', 'SET05_F32_02.png'])
#     dict_keys(['SET05_F08_01.png', 'SET05_F08_02.png'])
#     dict_keys(['SET05_F64_01.png', 'SET05_F64_02.png'])
#   dict_keys(['F32', 'F08', 'F64'])
#     dict_keys(['SET06_F32_01.png', 'SET06_F32_02.png'])
#     dict_keys(['SET06_F08_01.png', 'SET06_F08_02.png'])
#     dict_keys(['SET06_F64_01.png', 'SET06_F64_02.png'])
#   dict_keys(['F32', 'F08', 'F64'])
#     dict_keys(['SET07_F32_01.png', 'SET07_F32_02.png'])
#     dict_keys(['SET07_F08_01.png', 'SET07_F08_02.png'])
#     dict_keys(['SET07_F64_01.png', 'SET07_F64_02.png'])
#   dict_keys(['F32', 'F08', 'F64'])
#     dict_keys(['SET08_F32_01.png', 'SET08_F32_02.png'])
#     dict_keys(['SET08_F08_01.png', 'SET08_F08_02.png'])
#     dict_keys(['SET08_F64_01.png', 'SET08_F64_02.png'])
#   dict_keys(['F32', 'F08', 'F64'])
#     dict_keys(['SET09_F32_01.png', 'SET09_F32_02.png'])
#     dict_keys(['SET09_F08_01.png', 'SET09_F08_02.png'])
#     dict_keys(['SET09_F64_01.png', 'SET09_F64_02.png'])
# ====== load img_dict complete ======
# Denoising SET : SET01, f_num : F08 Start
# SET01_F08_10.png SET01 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_10.png
# SET01_F08_11.png SET01 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_11.png
# SET01_F08_12.png SET01 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_12.png
# SET01_F08_13.png SET01 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_13.png
# SET01_F08_14.png SET01 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_14.png
# SET01_F08_15.png SET01 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_15.png
# SET01_F08_16.png SET01 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_16.png
# SET01_F08_01.png SET01 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_01.png
# SET01_F08_02.png SET01 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_02.png
# SET01_F08_03.png SET01 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_03.png
# SET01_F08_04.png SET01 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_04.png
# SET01_F08_05.png SET01 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_05.png
# SET01_F08_06.png SET01 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_06.png
# SET01_F08_07.png SET01 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_07.png
# SET01_F08_08.png SET01 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_08.png
# SET01_F08_09.png SET01 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET01_F08_09.png
# Denoising SET : SET01, f_num : F08 End
# Denoising SET : SET02, f_num : F08 Start
# SET02_F08_10.png SET02 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_10.png
# SET02_F08_11.png SET02 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_11.png
# SET02_F08_12.png SET02 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_12.png
# SET02_F08_13.png SET02 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_13.png
# SET02_F08_14.png SET02 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_14.png
# SET02_F08_15.png SET02 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_15.png
# SET02_F08_16.png SET02 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_16.png
# SET02_F08_01.png SET02 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_01.png
# SET02_F08_02.png SET02 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_02.png
# SET02_F08_03.png SET02 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_03.png
# SET02_F08_04.png SET02 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_04.png
# SET02_F08_05.png SET02 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_05.png
# SET02_F08_06.png SET02 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_06.png
# SET02_F08_07.png SET02 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_07.png
# SET02_F08_08.png SET02 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_08.png
# SET02_F08_09.png SET02 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET02_F08_09.png
# Denoising SET : SET02, f_num : F08 End
# Denoising SET : SET03, f_num : F08 Start
# SET03_F08_10.png SET03 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_10.png
# SET03_F08_11.png SET03 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_11.png
# SET03_F08_12.png SET03 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_12.png
# SET03_F08_13.png SET03 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_13.png
# SET03_F08_14.png SET03 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_14.png
# SET03_F08_15.png SET03 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_15.png
# SET03_F08_16.png SET03 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_16.png
# SET03_F08_01.png SET03 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_01.png
# SET03_F08_02.png SET03 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_02.png
# SET03_F08_03.png SET03 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_03.png
# SET03_F08_04.png SET03 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_04.png
# SET03_F08_05.png SET03 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_05.png
# SET03_F08_06.png SET03 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_06.png
# SET03_F08_07.png SET03 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_07.png
# SET03_F08_08.png SET03 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_08.png
# SET03_F08_09.png SET03 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET03_F08_09.png
# Denoising SET : SET03, f_num : F08 End
# Denoising SET : SET04, f_num : F08 Start
# SET04_F08_10.png SET04 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_10.png
# SET04_F08_11.png SET04 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_11.png
# SET04_F08_12.png SET04 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_12.png
# SET04_F08_13.png SET04 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_13.png
# SET04_F08_14.png SET04 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_14.png
# SET04_F08_15.png SET04 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_15.png
# SET04_F08_16.png SET04 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_16.png
# SET04_F08_01.png SET04 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_01.png
# SET04_F08_02.png SET04 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_02.png
# SET04_F08_03.png SET04 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_03.png
# SET04_F08_04.png SET04 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_04.png
# SET04_F08_05.png SET04 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_05.png
# SET04_F08_06.png SET04 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_06.png
# SET04_F08_07.png SET04 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_07.png
# SET04_F08_08.png SET04 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_08.png
# SET04_F08_09.png SET04 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET04_F08_09.png
# Denoising SET : SET04, f_num : F08 End
# Denoising SET : SET10, f_num : F08 Start
# SET10_F08_01.png SET10 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET10_F08_01.png
# SET10_F08_02.png SET10 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET10_F08_02.png
# Denoising SET : SET10, f_num : F08 End
# Denoising SET : SET05, f_num : F08 Start
# SET05_F08_01.png SET05 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET05_F08_01.png
# SET05_F08_02.png SET05 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET05_F08_02.png
# Denoising SET : SET05, f_num : F08 End
# Denoising SET : SET06, f_num : F08 Start
# SET06_F08_01.png SET06 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET06_F08_01.png
# SET06_F08_02.png SET06 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET06_F08_02.png
# Denoising SET : SET06, f_num : F08 End
# Denoising SET : SET07, f_num : F08 Start
# SET07_F08_01.png SET07 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET07_F08_01.png
# SET07_F08_02.png SET07 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET07_F08_02.png
# Denoising SET : SET07, f_num : F08 End
# Denoising SET : SET08, f_num : F08 Start
# SET08_F08_01.png SET08 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET08_F08_01.png
# SET08_F08_02.png SET08 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET08_F08_02.png
# Denoising SET : SET08, f_num : F08 End
# Denoising SET : SET09, f_num : F08 Start
# SET09_F08_01.png SET09 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET09_F08_01.png
# SET09_F08_02.png SET09 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./N2N_output_230917_wholeimg_withSEM2_onSEM1//F08-F08_FBI_Net/SET09_F08_02.png
# Denoising SET : SET09, f_num : F08 End

# %%
refined_metric = {}
for key in metric.keys():
    # print(key)
    refined_metric[key] = {}
    for sub_key in metric[key].keys():     
        # print(key,sub_key)
        if type(metric[key][sub_key]) == dict:
            metric[key][sub_key] = list(metric[key][sub_key].values())
        refined_metric[key][f'{sub_key}'] = np.mean(metric[key][sub_key])
        

import pandas as pd
refined_metric = pd.DataFrame(refined_metric)
refined_metric
# Out:
# /mnt/ssd/hyun/fbi-net/env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /mnt/ssd/hyun/fbi-net/env/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#              median_filter        raw  F01-F01_FBI_Net_EMSE_Affine  \
# PSNR             17.663364  11.528837                    15.116227
# SSIM              0.357454   0.021546                     0.083735
# before_PSNR            NaN        NaN                          NaN
# before_SSIM            NaN        NaN                          NaN
#
#              F01-F01_FBI_Net  F01-F02_FBI_Net  F01-F04_FBI_Net  \
# PSNR               17.483187        17.639350        17.591006
# SSIM                0.352791         0.352513         0.351554
# before_PSNR              NaN              NaN              NaN
# before_SSIM              NaN              NaN              NaN
#
#              F01-F08_FBI_Net  F01-F32_FBI_Net  F01-F32_FBI_Net_MSE  \
# PSNR               17.322812        15.019464            15.283499
# SSIM                0.352502         0.315122             0.317341
# before_PSNR              NaN              NaN                  NaN
# before_SSIM              NaN              NaN                  NaN
#
#              F01-F01_FBI_Net_N2V  F02-F02_FBI_Net  F02-F04_FBI_Net  \
# PSNR                   15.139877        17.066696        17.201471
# SSIM                    0.081722         0.349900         0.350445
# before_PSNR                  NaN              NaN              NaN
# before_SSIM                  NaN              NaN              NaN
#
#              F04-F04_FBI_Net  F04-F08_FBI_Net  F08-F08_FBI_Net
# PSNR               17.136316        17.189326        18.329843
# SSIM                0.349227         0.348826         0.257482
# before_PSNR              NaN              NaN              NaN
# before_SSIM              NaN              NaN              NaN

# %%
refined_metric.drop(['before_PSNR','before_SSIM'],inplace=True)
refined_metric
# Out:
#       median_filter        raw  F01-F01_FBI_Net_EMSE_Affine  F01-F01_FBI_Net  \
# PSNR      17.663364  11.528837                    15.116227        17.483187
# SSIM       0.357454   0.021546                     0.083735         0.352791
#
#       F01-F02_FBI_Net  F01-F04_FBI_Net  F01-F08_FBI_Net  F01-F32_FBI_Net  \
# PSNR        17.639350        17.591006        17.322812        15.019464
# SSIM         0.352513         0.351554         0.352502         0.315122
#
#       F01-F32_FBI_Net_MSE  F01-F01_FBI_Net_N2V  F02-F02_FBI_Net  \
# PSNR            15.283499            15.139877        17.066696
# SSIM             0.317341             0.081722         0.349900
#
#       F02-F04_FBI_Net  F04-F04_FBI_Net  F04-F08_FBI_Net  F08-F08_FBI_Net
# PSNR        17.201471        17.136316        17.189326        18.329843
# SSIM         0.350445         0.349227         0.348826         0.257482

# %%
refined_metric.to_csv(f"{folder_name}/metric_whole_with_SEM2.csv")

# %%
from knockknock import telegram_sender
@telegram_sender(token='1531143270:AAFTord-4Bi370ohc39wGyYhjGi7_VjZTwU', chat_id=1597147353)
def denoising_end():
    print("Denoising End")
denoising_end()
# !date
# Out:
# Denoising End
# Fri Sep 29 17:08:18 UTC 2023

# %%
refined_metric.T.to_csv(f"{folder_name}/metric_whole_T_with_SEM2.csv")
