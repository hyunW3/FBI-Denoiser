# %%
import os 
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0" # "0,1,2,3" # "0"

# %%
import numpy as np
import h5py
import cv2
import os, sys, gc
import argparse
from glob import glob
from core.get_args import get_args
from core.produce_denoised_img import produce_denoised_img_no_crop
from core.utils import TedataLoader
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from core.watershed import watershed,watershed_per_img,watershed_original
from core.median_filter import apply_median_filter_cpu, apply_median_filter_gpu, apply_median_filter_gpu_simple
# %load_ext autoreload
# %autoreload 2

# %%
def load_img_dict(target_x,target_y,debug=True):
    possible_f_num = ['F01','F02','F04','F08','F16','F32']
    x_f_num = []
    if target_x == 'F#':
        for f_num in possible_f_num:
            if f_num != target_y:
                x_f_num.append(f_num)
            else :
                break
    else :
        x_f_num = [target_x]
    print(x_f_num)
    img_dict = {}
    path_list = ["/home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU",
                 "/home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung+SNU+dataset+221115"
                 ]
    # data_path = "/mnt/ssd/hyun/fbi-net/FBI-Denoiser/data/Samsung_SNU_1474x3010_aligned_ordered/" 
    debug = True
    for data_path in path_list:
        print("=====",data_path, "=====")
        for set_num in sorted(os.listdir(data_path)):
            if set_num[0] == '.' :
                continue
            set_path = os.path.join(data_path,set_num)
            set_number = set_num.split(" ")[-1][:-1]
            set_num = f"{set_num[1:4]}{set_number}"
            print("=====",set_num, "=====")
            img_dict[set_num] = {}
            # if debug is True:
            #     print(set_num)
            f_num_list = os.listdir(set_path)
            # print(f_num_list)
            for f_num in f_num_list:
                f_path = os.path.join(set_path,f_num)
                f_number = int(f_num[1:])
                f_num = f"F{f_number:02d}"
                # print(set_num,f_num)
                if f_num not in x_f_num:
                    continue
                # img_dict[set_num][f_num] = None
                img_dict[set_num][f_num] = {}
                img_list = sorted(os.listdir(f_path))
                img_list = list(filter(lambda x : ".ipynb_checkpoints" not in x,img_list))
                
                for filename in sorted(img_list):
                    
                    img_path = os.path.join(f_path,filename)
                    image_idx = int(filename.split("_")[0])
                    filename = f"{set_num}_{f_num}_{image_idx:02d}.png"
                    if debug is True:
                        print(f_num," & ",filename)
                    img = cv2.imread(img_path,cv2.IMREAD_GRAYSCALE) 
                    # img_dict[set_num][f_num].append(img)
                    # img = np.expand_dims(img,axis=0)
                    img = np.expand_dims(img,axis=0) / 255.
                    img_dict[set_num][f_num][filename] = img
                    # if img_dict[set_num][f_num] is None:  
                    #     img_dict[set_num][f_num] = img
                    # else :
                    #     img_dict[set_num][f_num] = np.append(img_dict[set_num][f_num],img,axis=0)
                    if debug is True:
                        print(set_num,f_num,img.shape)
    if debug is True:
        print(img_dict.keys())
        for set_num in img_dict.keys():
            print(" ",img_dict[set_num].keys())
            for f_num in img_dict[set_num].keys():
                print("   ",img_dict[set_num][f_num].keys())
    print("====== load img_dict complete ======")
    return img_dict

# %%
args = get_args()
args.pge_weight_dir = None #pge_weight_dir
args.loss_function = "MSE_Affine"
args.noise_type = 'Poisson-Gaussian'
args.model_type = 'FBI_Net'
# args.set_num = '1'
args.data_name = 'Samsung'
args.data_type = 'Grayscale'
args.lr = 0.001
args.num_layers = 17
args.num_filters = 64
# args.crop_size = 200
args.debug = False

# %%
gc.collect()
debug= True
target_fbi_weight = glob("../weights/*x_as_F08_y_as_F32_l1_on_img_gradient_*") + glob("../weights/*x_as_F01_y_as_F02_l1_on_img_gradient_*") 
for weight in target_fbi_weight:
    print(weight)
# Out:
# ../weights/230414_find_lambda_FBI_Net_Grayscale_Samsung_SET050607080910individual_x_as_F08_y_as_F32_l1_on_img_gradient_0.8_MSE_Affine_with_tv_layers_x17_filters_x64_cropsize_256.w
# ../weights/230414_find_lambda_FBI_Net_Grayscale_Samsung_SET050607080910individual_x_as_F08_y_as_F32_l1_on_img_gradient_0.3_MSE_Affine_with_tv_layers_x17_filters_x64_cropsize_256.w
# ../weights/230414_find_lambda_FBI_Net_Grayscale_Samsung_SET050607080910individual_x_as_F08_y_as_F32_l1_on_img_gradient_0.1_MSE_Affine_with_tv_layers_x17_filters_x64_cropsize_256.w
# ../weights/230414_find_lambda_FBI_Net_Grayscale_Samsung_SET050607080910x_as_F01_y_as_F02_l1_on_img_gradient_0.3_MSE_Affine_with_tv_layers_x17_filters_x64_cropsize_256.w
# ../weights/230414_find_lambda_FBI_Net_Grayscale_Samsung_SET050607080910x_as_F01_y_as_F02_l1_on_img_gradient_0.8_MSE_Affine_with_tv_layers_x17_filters_x64_cropsize_256.w
# ../weights/230414_find_lambda_FBI_Net_Grayscale_Samsung_SET050607080910x_as_F01_y_as_F02_l1_on_img_gradient_0.1_MSE_Affine_with_tv_layers_x17_filters_x64_cropsize_256.w

# %%
def parsing_weight_name(fbi_weight_dir):
    target_y = fbi_weight_dir.split("_y_as_")[1][:3]
    if "x_as_" in fbi_weight_dir:
        target_x = fbi_weight_dir.split("x_as_")[1][:3]
        if 'F#' in target_x:
            target_x = "F#"
    else :
        target_x = "F#"
    dataset_version = 'v1' if 'with_SET01020304' in fbi_weight_dir else 'v2'
    if "l1_on_img_gradient" in fbi_weight_dir:
        lambda_val = fbi_weight_dir.split("l1_on_img_gradient_")[1].split("_")[0]
        dataset_version += f"_l1_on_img_gradient_{lambda_val}"
    return target_x,target_y, dataset_version

# %%
for fbi_weight_dir in target_fbi_weight:

    target_x,target_y, dataset_version = parsing_weight_name(fbi_weight_dir)
    
    # if target_y not in ['F08','F16']:
    #     continue
    print("======",target_x,"vs",target_y,dataset_version," ======")
    if debug is True:
        print(fbi_weight_dir)
        # print(median_filter_input,"median_filter_input")
    folder_name = f"./denoised_img_{target_x}_vs_{target_y}_{dataset_version}"

        # folder_name += "_median_filter_input_but_not_used_at_inference"
    print("folder_name : ",folder_name)
    os.makedirs(folder_name,exist_ok=True)
    if target_x == 'F#':
        img_dict = load_img_dict('F01',target_y,debug=True)
    else :
        img_dict = load_img_dict(target_x,target_y,debug=True)
    
    
    model = produce_denoised_img_no_crop(_pge_weight_dir=None,_fbi_weight_dir = fbi_weight_dir,_args = args)
    
    # DENOISE IMAGE
    denoised_img_dict = {}
    for set_num in img_dict.keys():
        denoised_img_dict[set_num] = {}
        for f_num in img_dict[set_num].keys():
            denoised_img_dict[set_num][f_num] = None
            if f_num != target_x and target_x != 'F#':
                continue
            for idx,(filename, img) in enumerate(img_dict[set_num][f_num].items()):
                img = np.expand_dims(img, axis=0) # 1,1536x3074
                print(filename,set_num,f_num,idx,img.shape)
                    
                denoised_img = model.eval(img)[0]
                # print("after denoised",denoised_img.shape)
                if denoised_img_dict[set_num][f_num] is None:
                    denoised_img_dict[set_num][f_num] = denoised_img
                else :
                    denoised_img_dict[set_num][f_num] = np.append(denoised_img_dict[set_num][f_num], denoised_img,axis=0)
                # filename = f"{set_num}_{f_num}_{idx}.png"
                # if os.path.isfile(f"{folder_name}/{filename}"):
                #     print("already exist : ",f"{folder_name}/{filename}")
                #     continue
                # else :
                #     print("imwrite : ",f"{folder_name}/{filename}")
                #     cv2.imwrite(f"{folder_name}/{filename}",denoised_img[0]*255)
                print("imwrite : ",f"{folder_name}/{filename}")
                cv2.imwrite(f"{folder_name}/{filename}",denoised_img[0]*255)
                
            print(f"Denoising SET : {set_num}, f_num : {f_num} End")
            
    # np.save(f"./intermediate_result/{folder_name}_denoised_img_dict.npy",denoised_img_dict)
    import zipfile



    zip_file = zipfile.ZipFile(folder_name + ".zip", "w")  # "w": write 모드
    for file in os.listdir(folder_name):
        if file.endswith('.png'):
            zip_file.write(os.path.join(folder_name, file), compress_type=zipfile.ZIP_DEFLATED)

    zip_file.close()
    gc.collect()
# Out:
# ====== F08 vs F32 v2_l1_on_img_gradient_0.8  ======
# ../weights/230414_find_lambda_FBI_Net_Grayscale_Samsung_SET050607080910individual_x_as_F08_y_as_F32_l1_on_img_gradient_0.8_MSE_Affine_with_tv_layers_x17_filters_x64_cropsize_256.w
# folder_name :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8
# ['F08']
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU =====
# ===== SET1 =====
# F08  &  SET1_F08_10.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_11.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_12.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_13.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_14.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_15.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_16.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_01.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_02.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_03.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_04.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_05.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_06.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_07.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_08.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_09.png
# SET1 F08 (1, 2048, 3072)
# ===== SET2 =====
# F08  &  SET2_F08_10.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_11.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_12.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_13.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_14.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_15.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_16.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_01.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_02.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_03.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_04.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_05.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_06.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_07.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_08.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_09.png
# SET2 F08 (1, 2048, 3072)
# ===== SET3 =====
# F08  &  SET3_F08_10.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_11.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_12.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_13.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_14.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_15.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_16.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_01.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_02.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_03.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_04.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_05.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_06.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_07.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_08.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_09.png
# SET3 F08 (1, 2048, 3072)
# ===== SET4 =====
# F08  &  SET4_F08_10.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_11.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_12.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_13.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_14.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_15.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_16.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_01.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_02.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_03.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_04.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_05.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_06.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_07.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_08.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_09.png
# SET4 F08 (1, 2048, 3072)
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung+SNU+dataset+221115 =====
# ===== SET10 =====
# F08  &  SET10_F08_01.png
# SET10 F08 (1, 2048, 3072)
# F08  &  SET10_F08_02.png
# SET10 F08 (1, 2048, 3072)
# ===== SET5 =====
# F08  &  SET5_F08_01.png
# SET5 F08 (1, 2048, 3072)
# F08  &  SET5_F08_02.png
# SET5 F08 (1, 2048, 3072)
# ===== SET6 =====
# F08  &  SET6_F08_01.png
# SET6 F08 (1, 2048, 3072)
# F08  &  SET6_F08_02.png
# SET6 F08 (1, 2048, 3072)
# ===== SET7 =====
# F08  &  SET7_F08_01.png
# SET7 F08 (1, 2048, 3072)
# F08  &  SET7_F08_02.png
# SET7 F08 (1, 2048, 3072)
# ===== SET8 =====
# F08  &  SET8_F08_01.png
# SET8 F08 (1, 2048, 3072)
# F08  &  SET8_F08_02.png
# SET8 F08 (1, 2048, 3072)
# ===== SET9 =====
# F08  &  SET9_F08_01.png
# SET9 F08 (1, 2048, 3072)
# F08  &  SET9_F08_02.png
# SET9 F08 (1, 2048, 3072)
# dict_keys(['SET1', 'SET2', 'SET3', 'SET4', 'SET10', 'SET5', 'SET6', 'SET7', 'SET8', 'SET9'])
#   dict_keys(['F08'])
#     dict_keys(['SET1_F08_10.png', 'SET1_F08_11.png', 'SET1_F08_12.png', 'SET1_F08_13.png', 'SET1_F08_14.png', 'SET1_F08_15.png', 'SET1_F08_16.png', 'SET1_F08_01.png', 'SET1_F08_02.png', 'SET1_F08_03.png', 'SET1_F08_04.png', 'SET1_F08_05.png', 'SET1_F08_06.png', 'SET1_F08_07.png', 'SET1_F08_08.png', 'SET1_F08_09.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET2_F08_10.png', 'SET2_F08_11.png', 'SET2_F08_12.png', 'SET2_F08_13.png', 'SET2_F08_14.png', 'SET2_F08_15.png', 'SET2_F08_16.png', 'SET2_F08_01.png', 'SET2_F08_02.png', 'SET2_F08_03.png', 'SET2_F08_04.png', 'SET2_F08_05.png', 'SET2_F08_06.png', 'SET2_F08_07.png', 'SET2_F08_08.png', 'SET2_F08_09.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET3_F08_10.png', 'SET3_F08_11.png', 'SET3_F08_12.png', 'SET3_F08_13.png', 'SET3_F08_14.png', 'SET3_F08_15.png', 'SET3_F08_16.png', 'SET3_F08_01.png', 'SET3_F08_02.png', 'SET3_F08_03.png', 'SET3_F08_04.png', 'SET3_F08_05.png', 'SET3_F08_06.png', 'SET3_F08_07.png', 'SET3_F08_08.png', 'SET3_F08_09.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET4_F08_10.png', 'SET4_F08_11.png', 'SET4_F08_12.png', 'SET4_F08_13.png', 'SET4_F08_14.png', 'SET4_F08_15.png', 'SET4_F08_16.png', 'SET4_F08_01.png', 'SET4_F08_02.png', 'SET4_F08_03.png', 'SET4_F08_04.png', 'SET4_F08_05.png', 'SET4_F08_06.png', 'SET4_F08_07.png', 'SET4_F08_08.png', 'SET4_F08_09.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET10_F08_01.png', 'SET10_F08_02.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET5_F08_01.png', 'SET5_F08_02.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET6_F08_01.png', 'SET6_F08_02.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET7_F08_01.png', 'SET7_F08_02.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET8_F08_01.png', 'SET8_F08_02.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET9_F08_01.png', 'SET9_F08_02.png'])
# ====== load img_dict complete ======
# SET1_F08_10.png SET1 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_10.png
# SET1_F08_11.png SET1 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_11.png
# SET1_F08_12.png SET1 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_12.png
# SET1_F08_13.png SET1 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_13.png
# SET1_F08_14.png SET1 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_14.png
# SET1_F08_15.png SET1 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_15.png
# SET1_F08_16.png SET1 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_16.png
# SET1_F08_01.png SET1 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_01.png
# SET1_F08_02.png SET1 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_02.png
# SET1_F08_03.png SET1 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_03.png
# SET1_F08_04.png SET1 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_04.png
# SET1_F08_05.png SET1 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_05.png
# SET1_F08_06.png SET1 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_06.png
# SET1_F08_07.png SET1 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_07.png
# SET1_F08_08.png SET1 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_08.png
# SET1_F08_09.png SET1 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET1_F08_09.png
# Denoising SET : SET1, f_num : F08 End
# SET2_F08_10.png SET2 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_10.png
# SET2_F08_11.png SET2 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_11.png
# SET2_F08_12.png SET2 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_12.png
# SET2_F08_13.png SET2 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_13.png
# SET2_F08_14.png SET2 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_14.png
# SET2_F08_15.png SET2 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_15.png
# SET2_F08_16.png SET2 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_16.png
# SET2_F08_01.png SET2 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_01.png
# SET2_F08_02.png SET2 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_02.png
# SET2_F08_03.png SET2 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_03.png
# SET2_F08_04.png SET2 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_04.png
# SET2_F08_05.png SET2 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_05.png
# SET2_F08_06.png SET2 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_06.png
# SET2_F08_07.png SET2 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_07.png
# SET2_F08_08.png SET2 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_08.png
# SET2_F08_09.png SET2 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET2_F08_09.png
# Denoising SET : SET2, f_num : F08 End
# SET3_F08_10.png SET3 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_10.png
# SET3_F08_11.png SET3 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_11.png
# SET3_F08_12.png SET3 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_12.png
# SET3_F08_13.png SET3 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_13.png
# SET3_F08_14.png SET3 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_14.png
# SET3_F08_15.png SET3 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_15.png
# SET3_F08_16.png SET3 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_16.png
# SET3_F08_01.png SET3 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_01.png
# SET3_F08_02.png SET3 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_02.png
# SET3_F08_03.png SET3 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_03.png
# SET3_F08_04.png SET3 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_04.png
# SET3_F08_05.png SET3 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_05.png
# SET3_F08_06.png SET3 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_06.png
# SET3_F08_07.png SET3 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_07.png
# SET3_F08_08.png SET3 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_08.png
# SET3_F08_09.png SET3 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET3_F08_09.png
# Denoising SET : SET3, f_num : F08 End
# SET4_F08_10.png SET4 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_10.png
# SET4_F08_11.png SET4 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_11.png
# SET4_F08_12.png SET4 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_12.png
# SET4_F08_13.png SET4 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_13.png
# SET4_F08_14.png SET4 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_14.png
# SET4_F08_15.png SET4 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_15.png
# SET4_F08_16.png SET4 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_16.png
# SET4_F08_01.png SET4 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_01.png
# SET4_F08_02.png SET4 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_02.png
# SET4_F08_03.png SET4 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_03.png
# SET4_F08_04.png SET4 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_04.png
# SET4_F08_05.png SET4 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_05.png
# SET4_F08_06.png SET4 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_06.png
# SET4_F08_07.png SET4 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_07.png
# SET4_F08_08.png SET4 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_08.png
# SET4_F08_09.png SET4 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET4_F08_09.png
# Denoising SET : SET4, f_num : F08 End
# SET10_F08_01.png SET10 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET10_F08_01.png
# SET10_F08_02.png SET10 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET10_F08_02.png
# Denoising SET : SET10, f_num : F08 End
# SET5_F08_01.png SET5 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET5_F08_01.png
# SET5_F08_02.png SET5 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET5_F08_02.png
# Denoising SET : SET5, f_num : F08 End
# SET6_F08_01.png SET6 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET6_F08_01.png
# SET6_F08_02.png SET6 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET6_F08_02.png
# Denoising SET : SET6, f_num : F08 End
# SET7_F08_01.png SET7 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET7_F08_01.png
# SET7_F08_02.png SET7 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET7_F08_02.png
# Denoising SET : SET7, f_num : F08 End
# SET8_F08_01.png SET8 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET8_F08_01.png
# SET8_F08_02.png SET8 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET8_F08_02.png
# Denoising SET : SET8, f_num : F08 End
# SET9_F08_01.png SET9 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET9_F08_01.png
# SET9_F08_02.png SET9 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.8/SET9_F08_02.png
# Denoising SET : SET9, f_num : F08 End
# ====== F08 vs F32 v2_l1_on_img_gradient_0.3  ======
# ../weights/230414_find_lambda_FBI_Net_Grayscale_Samsung_SET050607080910individual_x_as_F08_y_as_F32_l1_on_img_gradient_0.3_MSE_Affine_with_tv_layers_x17_filters_x64_cropsize_256.w
# folder_name :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3
# ['F08']
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU =====
# ===== SET1 =====
# F08  &  SET1_F08_10.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_11.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_12.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_13.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_14.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_15.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_16.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_01.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_02.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_03.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_04.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_05.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_06.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_07.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_08.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_09.png
# SET1 F08 (1, 2048, 3072)
# ===== SET2 =====
# F08  &  SET2_F08_10.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_11.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_12.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_13.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_14.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_15.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_16.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_01.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_02.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_03.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_04.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_05.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_06.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_07.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_08.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_09.png
# SET2 F08 (1, 2048, 3072)
# ===== SET3 =====
# F08  &  SET3_F08_10.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_11.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_12.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_13.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_14.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_15.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_16.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_01.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_02.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_03.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_04.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_05.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_06.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_07.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_08.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_09.png
# SET3 F08 (1, 2048, 3072)
# ===== SET4 =====
# F08  &  SET4_F08_10.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_11.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_12.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_13.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_14.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_15.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_16.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_01.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_02.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_03.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_04.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_05.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_06.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_07.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_08.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_09.png
# SET4 F08 (1, 2048, 3072)
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung+SNU+dataset+221115 =====
# ===== SET10 =====
# F08  &  SET10_F08_01.png
# SET10 F08 (1, 2048, 3072)
# F08  &  SET10_F08_02.png
# SET10 F08 (1, 2048, 3072)
# ===== SET5 =====
# F08  &  SET5_F08_01.png
# SET5 F08 (1, 2048, 3072)
# F08  &  SET5_F08_02.png
# SET5 F08 (1, 2048, 3072)
# ===== SET6 =====
# F08  &  SET6_F08_01.png
# SET6 F08 (1, 2048, 3072)
# F08  &  SET6_F08_02.png
# SET6 F08 (1, 2048, 3072)
# ===== SET7 =====
# F08  &  SET7_F08_01.png
# SET7 F08 (1, 2048, 3072)
# F08  &  SET7_F08_02.png
# SET7 F08 (1, 2048, 3072)
# ===== SET8 =====
# F08  &  SET8_F08_01.png
# SET8 F08 (1, 2048, 3072)
# F08  &  SET8_F08_02.png
# SET8 F08 (1, 2048, 3072)
# ===== SET9 =====
# F08  &  SET9_F08_01.png
# SET9 F08 (1, 2048, 3072)
# F08  &  SET9_F08_02.png
# SET9 F08 (1, 2048, 3072)
# dict_keys(['SET1', 'SET2', 'SET3', 'SET4', 'SET10', 'SET5', 'SET6', 'SET7', 'SET8', 'SET9'])
#   dict_keys(['F08'])
#     dict_keys(['SET1_F08_10.png', 'SET1_F08_11.png', 'SET1_F08_12.png', 'SET1_F08_13.png', 'SET1_F08_14.png', 'SET1_F08_15.png', 'SET1_F08_16.png', 'SET1_F08_01.png', 'SET1_F08_02.png', 'SET1_F08_03.png', 'SET1_F08_04.png', 'SET1_F08_05.png', 'SET1_F08_06.png', 'SET1_F08_07.png', 'SET1_F08_08.png', 'SET1_F08_09.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET2_F08_10.png', 'SET2_F08_11.png', 'SET2_F08_12.png', 'SET2_F08_13.png', 'SET2_F08_14.png', 'SET2_F08_15.png', 'SET2_F08_16.png', 'SET2_F08_01.png', 'SET2_F08_02.png', 'SET2_F08_03.png', 'SET2_F08_04.png', 'SET2_F08_05.png', 'SET2_F08_06.png', 'SET2_F08_07.png', 'SET2_F08_08.png', 'SET2_F08_09.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET3_F08_10.png', 'SET3_F08_11.png', 'SET3_F08_12.png', 'SET3_F08_13.png', 'SET3_F08_14.png', 'SET3_F08_15.png', 'SET3_F08_16.png', 'SET3_F08_01.png', 'SET3_F08_02.png', 'SET3_F08_03.png', 'SET3_F08_04.png', 'SET3_F08_05.png', 'SET3_F08_06.png', 'SET3_F08_07.png', 'SET3_F08_08.png', 'SET3_F08_09.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET4_F08_10.png', 'SET4_F08_11.png', 'SET4_F08_12.png', 'SET4_F08_13.png', 'SET4_F08_14.png', 'SET4_F08_15.png', 'SET4_F08_16.png', 'SET4_F08_01.png', 'SET4_F08_02.png', 'SET4_F08_03.png', 'SET4_F08_04.png', 'SET4_F08_05.png', 'SET4_F08_06.png', 'SET4_F08_07.png', 'SET4_F08_08.png', 'SET4_F08_09.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET10_F08_01.png', 'SET10_F08_02.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET5_F08_01.png', 'SET5_F08_02.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET6_F08_01.png', 'SET6_F08_02.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET7_F08_01.png', 'SET7_F08_02.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET8_F08_01.png', 'SET8_F08_02.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET9_F08_01.png', 'SET9_F08_02.png'])
# ====== load img_dict complete ======
# SET1_F08_10.png SET1 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_10.png
# SET1_F08_11.png SET1 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_11.png
# SET1_F08_12.png SET1 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_12.png
# SET1_F08_13.png SET1 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_13.png
# SET1_F08_14.png SET1 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_14.png
# SET1_F08_15.png SET1 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_15.png
# SET1_F08_16.png SET1 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_16.png
# SET1_F08_01.png SET1 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_01.png
# SET1_F08_02.png SET1 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_02.png
# SET1_F08_03.png SET1 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_03.png
# SET1_F08_04.png SET1 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_04.png
# SET1_F08_05.png SET1 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_05.png
# SET1_F08_06.png SET1 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_06.png
# SET1_F08_07.png SET1 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_07.png
# SET1_F08_08.png SET1 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_08.png
# SET1_F08_09.png SET1 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET1_F08_09.png
# Denoising SET : SET1, f_num : F08 End
# SET2_F08_10.png SET2 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_10.png
# SET2_F08_11.png SET2 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_11.png
# SET2_F08_12.png SET2 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_12.png
# SET2_F08_13.png SET2 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_13.png
# SET2_F08_14.png SET2 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_14.png
# SET2_F08_15.png SET2 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_15.png
# SET2_F08_16.png SET2 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_16.png
# SET2_F08_01.png SET2 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_01.png
# SET2_F08_02.png SET2 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_02.png
# SET2_F08_03.png SET2 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_03.png
# SET2_F08_04.png SET2 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_04.png
# SET2_F08_05.png SET2 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_05.png
# SET2_F08_06.png SET2 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_06.png
# SET2_F08_07.png SET2 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_07.png
# SET2_F08_08.png SET2 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_08.png
# SET2_F08_09.png SET2 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET2_F08_09.png
# Denoising SET : SET2, f_num : F08 End
# SET3_F08_10.png SET3 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_10.png
# SET3_F08_11.png SET3 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_11.png
# SET3_F08_12.png SET3 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_12.png
# SET3_F08_13.png SET3 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_13.png
# SET3_F08_14.png SET3 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_14.png
# SET3_F08_15.png SET3 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_15.png
# SET3_F08_16.png SET3 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_16.png
# SET3_F08_01.png SET3 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_01.png
# SET3_F08_02.png SET3 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_02.png
# SET3_F08_03.png SET3 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_03.png
# SET3_F08_04.png SET3 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_04.png
# SET3_F08_05.png SET3 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_05.png
# SET3_F08_06.png SET3 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_06.png
# SET3_F08_07.png SET3 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_07.png
# SET3_F08_08.png SET3 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_08.png
# SET3_F08_09.png SET3 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET3_F08_09.png
# Denoising SET : SET3, f_num : F08 End
# SET4_F08_10.png SET4 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_10.png
# SET4_F08_11.png SET4 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_11.png
# SET4_F08_12.png SET4 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_12.png
# SET4_F08_13.png SET4 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_13.png
# SET4_F08_14.png SET4 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_14.png
# SET4_F08_15.png SET4 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_15.png
# SET4_F08_16.png SET4 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_16.png
# SET4_F08_01.png SET4 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_01.png
# SET4_F08_02.png SET4 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_02.png
# SET4_F08_03.png SET4 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_03.png
# SET4_F08_04.png SET4 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_04.png
# SET4_F08_05.png SET4 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_05.png
# SET4_F08_06.png SET4 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_06.png
# SET4_F08_07.png SET4 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_07.png
# SET4_F08_08.png SET4 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_08.png
# SET4_F08_09.png SET4 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET4_F08_09.png
# Denoising SET : SET4, f_num : F08 End
# SET10_F08_01.png SET10 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET10_F08_01.png
# SET10_F08_02.png SET10 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET10_F08_02.png
# Denoising SET : SET10, f_num : F08 End
# SET5_F08_01.png SET5 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET5_F08_01.png
# SET5_F08_02.png SET5 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET5_F08_02.png
# Denoising SET : SET5, f_num : F08 End
# SET6_F08_01.png SET6 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET6_F08_01.png
# SET6_F08_02.png SET6 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET6_F08_02.png
# Denoising SET : SET6, f_num : F08 End
# SET7_F08_01.png SET7 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET7_F08_01.png
# SET7_F08_02.png SET7 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET7_F08_02.png
# Denoising SET : SET7, f_num : F08 End
# SET8_F08_01.png SET8 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET8_F08_01.png
# SET8_F08_02.png SET8 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET8_F08_02.png
# Denoising SET : SET8, f_num : F08 End
# SET9_F08_01.png SET9 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET9_F08_01.png
# SET9_F08_02.png SET9 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.3/SET9_F08_02.png
# Denoising SET : SET9, f_num : F08 End
# ====== F08 vs F32 v2_l1_on_img_gradient_0.1  ======
# ../weights/230414_find_lambda_FBI_Net_Grayscale_Samsung_SET050607080910individual_x_as_F08_y_as_F32_l1_on_img_gradient_0.1_MSE_Affine_with_tv_layers_x17_filters_x64_cropsize_256.w
# folder_name :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1
# ['F08']
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU =====
# ===== SET1 =====
# F08  &  SET1_F08_10.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_11.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_12.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_13.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_14.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_15.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_16.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_01.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_02.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_03.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_04.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_05.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_06.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_07.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_08.png
# SET1 F08 (1, 2048, 3072)
# F08  &  SET1_F08_09.png
# SET1 F08 (1, 2048, 3072)
# ===== SET2 =====
# F08  &  SET2_F08_10.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_11.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_12.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_13.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_14.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_15.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_16.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_01.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_02.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_03.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_04.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_05.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_06.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_07.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_08.png
# SET2 F08 (1, 2048, 3072)
# F08  &  SET2_F08_09.png
# SET2 F08 (1, 2048, 3072)
# ===== SET3 =====
# F08  &  SET3_F08_10.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_11.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_12.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_13.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_14.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_15.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_16.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_01.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_02.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_03.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_04.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_05.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_06.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_07.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_08.png
# SET3 F08 (1, 2048, 3072)
# F08  &  SET3_F08_09.png
# SET3 F08 (1, 2048, 3072)
# ===== SET4 =====
# F08  &  SET4_F08_10.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_11.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_12.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_13.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_14.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_15.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_16.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_01.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_02.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_03.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_04.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_05.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_06.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_07.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_08.png
# SET4 F08 (1, 2048, 3072)
# F08  &  SET4_F08_09.png
# SET4 F08 (1, 2048, 3072)
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung+SNU+dataset+221115 =====
# ===== SET10 =====
# F08  &  SET10_F08_01.png
# SET10 F08 (1, 2048, 3072)
# F08  &  SET10_F08_02.png
# SET10 F08 (1, 2048, 3072)
# ===== SET5 =====
# F08  &  SET5_F08_01.png
# SET5 F08 (1, 2048, 3072)
# F08  &  SET5_F08_02.png
# SET5 F08 (1, 2048, 3072)
# ===== SET6 =====
# F08  &  SET6_F08_01.png
# SET6 F08 (1, 2048, 3072)
# F08  &  SET6_F08_02.png
# SET6 F08 (1, 2048, 3072)
# ===== SET7 =====
# F08  &  SET7_F08_01.png
# SET7 F08 (1, 2048, 3072)
# F08  &  SET7_F08_02.png
# SET7 F08 (1, 2048, 3072)
# ===== SET8 =====
# F08  &  SET8_F08_01.png
# SET8 F08 (1, 2048, 3072)
# F08  &  SET8_F08_02.png
# SET8 F08 (1, 2048, 3072)
# ===== SET9 =====
# F08  &  SET9_F08_01.png
# SET9 F08 (1, 2048, 3072)
# F08  &  SET9_F08_02.png
# SET9 F08 (1, 2048, 3072)
# dict_keys(['SET1', 'SET2', 'SET3', 'SET4', 'SET10', 'SET5', 'SET6', 'SET7', 'SET8', 'SET9'])
#   dict_keys(['F08'])
#     dict_keys(['SET1_F08_10.png', 'SET1_F08_11.png', 'SET1_F08_12.png', 'SET1_F08_13.png', 'SET1_F08_14.png', 'SET1_F08_15.png', 'SET1_F08_16.png', 'SET1_F08_01.png', 'SET1_F08_02.png', 'SET1_F08_03.png', 'SET1_F08_04.png', 'SET1_F08_05.png', 'SET1_F08_06.png', 'SET1_F08_07.png', 'SET1_F08_08.png', 'SET1_F08_09.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET2_F08_10.png', 'SET2_F08_11.png', 'SET2_F08_12.png', 'SET2_F08_13.png', 'SET2_F08_14.png', 'SET2_F08_15.png', 'SET2_F08_16.png', 'SET2_F08_01.png', 'SET2_F08_02.png', 'SET2_F08_03.png', 'SET2_F08_04.png', 'SET2_F08_05.png', 'SET2_F08_06.png', 'SET2_F08_07.png', 'SET2_F08_08.png', 'SET2_F08_09.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET3_F08_10.png', 'SET3_F08_11.png', 'SET3_F08_12.png', 'SET3_F08_13.png', 'SET3_F08_14.png', 'SET3_F08_15.png', 'SET3_F08_16.png', 'SET3_F08_01.png', 'SET3_F08_02.png', 'SET3_F08_03.png', 'SET3_F08_04.png', 'SET3_F08_05.png', 'SET3_F08_06.png', 'SET3_F08_07.png', 'SET3_F08_08.png', 'SET3_F08_09.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET4_F08_10.png', 'SET4_F08_11.png', 'SET4_F08_12.png', 'SET4_F08_13.png', 'SET4_F08_14.png', 'SET4_F08_15.png', 'SET4_F08_16.png', 'SET4_F08_01.png', 'SET4_F08_02.png', 'SET4_F08_03.png', 'SET4_F08_04.png', 'SET4_F08_05.png', 'SET4_F08_06.png', 'SET4_F08_07.png', 'SET4_F08_08.png', 'SET4_F08_09.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET10_F08_01.png', 'SET10_F08_02.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET5_F08_01.png', 'SET5_F08_02.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET6_F08_01.png', 'SET6_F08_02.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET7_F08_01.png', 'SET7_F08_02.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET8_F08_01.png', 'SET8_F08_02.png'])
#   dict_keys(['F08'])
#     dict_keys(['SET9_F08_01.png', 'SET9_F08_02.png'])
# ====== load img_dict complete ======
# SET1_F08_10.png SET1 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_10.png
# SET1_F08_11.png SET1 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_11.png
# SET1_F08_12.png SET1 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_12.png
# SET1_F08_13.png SET1 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_13.png
# SET1_F08_14.png SET1 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_14.png
# SET1_F08_15.png SET1 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_15.png
# SET1_F08_16.png SET1 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_16.png
# SET1_F08_01.png SET1 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_01.png
# SET1_F08_02.png SET1 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_02.png
# SET1_F08_03.png SET1 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_03.png
# SET1_F08_04.png SET1 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_04.png
# SET1_F08_05.png SET1 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_05.png
# SET1_F08_06.png SET1 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_06.png
# SET1_F08_07.png SET1 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_07.png
# SET1_F08_08.png SET1 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_08.png
# SET1_F08_09.png SET1 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET1_F08_09.png
# Denoising SET : SET1, f_num : F08 End
# SET2_F08_10.png SET2 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_10.png
# SET2_F08_11.png SET2 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_11.png
# SET2_F08_12.png SET2 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_12.png
# SET2_F08_13.png SET2 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_13.png
# SET2_F08_14.png SET2 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_14.png
# SET2_F08_15.png SET2 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_15.png
# SET2_F08_16.png SET2 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_16.png
# SET2_F08_01.png SET2 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_01.png
# SET2_F08_02.png SET2 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_02.png
# SET2_F08_03.png SET2 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_03.png
# SET2_F08_04.png SET2 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_04.png
# SET2_F08_05.png SET2 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_05.png
# SET2_F08_06.png SET2 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_06.png
# SET2_F08_07.png SET2 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_07.png
# SET2_F08_08.png SET2 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_08.png
# SET2_F08_09.png SET2 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET2_F08_09.png
# Denoising SET : SET2, f_num : F08 End
# SET3_F08_10.png SET3 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_10.png
# SET3_F08_11.png SET3 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_11.png
# SET3_F08_12.png SET3 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_12.png
# SET3_F08_13.png SET3 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_13.png
# SET3_F08_14.png SET3 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_14.png
# SET3_F08_15.png SET3 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_15.png
# SET3_F08_16.png SET3 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_16.png
# SET3_F08_01.png SET3 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_01.png
# SET3_F08_02.png SET3 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_02.png
# SET3_F08_03.png SET3 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_03.png
# SET3_F08_04.png SET3 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_04.png
# SET3_F08_05.png SET3 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_05.png
# SET3_F08_06.png SET3 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_06.png
# SET3_F08_07.png SET3 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_07.png
# SET3_F08_08.png SET3 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_08.png
# SET3_F08_09.png SET3 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET3_F08_09.png
# Denoising SET : SET3, f_num : F08 End
# SET4_F08_10.png SET4 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_10.png
# SET4_F08_11.png SET4 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_11.png
# SET4_F08_12.png SET4 F08 2 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_12.png
# SET4_F08_13.png SET4 F08 3 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_13.png
# SET4_F08_14.png SET4 F08 4 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_14.png
# SET4_F08_15.png SET4 F08 5 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_15.png
# SET4_F08_16.png SET4 F08 6 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_16.png
# SET4_F08_01.png SET4 F08 7 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_01.png
# SET4_F08_02.png SET4 F08 8 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_02.png
# SET4_F08_03.png SET4 F08 9 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_03.png
# SET4_F08_04.png SET4 F08 10 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_04.png
# SET4_F08_05.png SET4 F08 11 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_05.png
# SET4_F08_06.png SET4 F08 12 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_06.png
# SET4_F08_07.png SET4 F08 13 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_07.png
# SET4_F08_08.png SET4 F08 14 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_08.png
# SET4_F08_09.png SET4 F08 15 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET4_F08_09.png
# Denoising SET : SET4, f_num : F08 End
# SET10_F08_01.png SET10 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET10_F08_01.png
# SET10_F08_02.png SET10 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET10_F08_02.png
# Denoising SET : SET10, f_num : F08 End
# SET5_F08_01.png SET5 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET5_F08_01.png
# SET5_F08_02.png SET5 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET5_F08_02.png
# Denoising SET : SET5, f_num : F08 End
# SET6_F08_01.png SET6 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET6_F08_01.png
# SET6_F08_02.png SET6 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET6_F08_02.png
# Denoising SET : SET6, f_num : F08 End
# SET7_F08_01.png SET7 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET7_F08_01.png
# SET7_F08_02.png SET7 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET7_F08_02.png
# Denoising SET : SET7, f_num : F08 End
# SET8_F08_01.png SET8 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET8_F08_01.png
# SET8_F08_02.png SET8 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET8_F08_02.png
# Denoising SET : SET8, f_num : F08 End
# SET9_F08_01.png SET9 F08 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET9_F08_01.png
# SET9_F08_02.png SET9 F08 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F08_vs_F32_v2_l1_on_img_gradient_0.1/SET9_F08_02.png
# Denoising SET : SET9, f_num : F08 End
# ====== F01 vs F02 v2_l1_on_img_gradient_0.3  ======
# ../weights/230414_find_lambda_FBI_Net_Grayscale_Samsung_SET050607080910x_as_F01_y_as_F02_l1_on_img_gradient_0.3_MSE_Affine_with_tv_layers_x17_filters_x64_cropsize_256.w
# folder_name :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.3
# ['F01']
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU =====
# ===== SET1 =====
# ===== SET2 =====
# ===== SET3 =====
# ===== SET4 =====
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung+SNU+dataset+221115 =====
# ===== SET10 =====
# F01  &  SET10_F01_01.png
# SET10 F01 (1, 2048, 3072)
# F01  &  SET10_F01_02.png
# SET10 F01 (1, 2048, 3072)
# ===== SET5 =====
# F01  &  SET5_F01_01.png
# SET5 F01 (1, 2048, 3072)
# F01  &  SET5_F01_02.png
# SET5 F01 (1, 2048, 3072)
# ===== SET6 =====
# F01  &  SET6_F01_01.png
# SET6 F01 (1, 2048, 3072)
# F01  &  SET6_F01_02.png
# SET6 F01 (1, 2048, 3072)
# ===== SET7 =====
# F01  &  SET7_F01_01.png
# SET7 F01 (1, 2048, 3072)
# F01  &  SET7_F01_02.png
# SET7 F01 (1, 2048, 3072)
# ===== SET8 =====
# F01  &  SET8_F01_01.png
# SET8 F01 (1, 2048, 3072)
# F01  &  SET8_F01_02.png
# SET8 F01 (1, 2048, 3072)
# ===== SET9 =====
# F01  &  SET9_F01_01.png
# SET9 F01 (1, 2048, 3072)
# F01  &  SET9_F01_02.png
# SET9 F01 (1, 2048, 3072)
# dict_keys(['SET1', 'SET2', 'SET3', 'SET4', 'SET10', 'SET5', 'SET6', 'SET7', 'SET8', 'SET9'])
#   dict_keys([])
#   dict_keys([])
#   dict_keys([])
#   dict_keys([])
#   dict_keys(['F01'])
#     dict_keys(['SET10_F01_01.png', 'SET10_F01_02.png'])
#   dict_keys(['F01'])
#     dict_keys(['SET5_F01_01.png', 'SET5_F01_02.png'])
#   dict_keys(['F01'])
#     dict_keys(['SET6_F01_01.png', 'SET6_F01_02.png'])
#   dict_keys(['F01'])
#     dict_keys(['SET7_F01_01.png', 'SET7_F01_02.png'])
#   dict_keys(['F01'])
#     dict_keys(['SET8_F01_01.png', 'SET8_F01_02.png'])
#   dict_keys(['F01'])
#     dict_keys(['SET9_F01_01.png', 'SET9_F01_02.png'])
# ====== load img_dict complete ======
# SET10_F01_01.png SET10 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.3/SET10_F01_01.png
# SET10_F01_02.png SET10 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.3/SET10_F01_02.png
# Denoising SET : SET10, f_num : F01 End
# SET5_F01_01.png SET5 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.3/SET5_F01_01.png
# SET5_F01_02.png SET5 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.3/SET5_F01_02.png
# Denoising SET : SET5, f_num : F01 End
# SET6_F01_01.png SET6 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.3/SET6_F01_01.png
# SET6_F01_02.png SET6 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.3/SET6_F01_02.png
# Denoising SET : SET6, f_num : F01 End
# SET7_F01_01.png SET7 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.3/SET7_F01_01.png
# SET7_F01_02.png SET7 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.3/SET7_F01_02.png
# Denoising SET : SET7, f_num : F01 End
# SET8_F01_01.png SET8 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.3/SET8_F01_01.png
# SET8_F01_02.png SET8 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.3/SET8_F01_02.png
# Denoising SET : SET8, f_num : F01 End
# SET9_F01_01.png SET9 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.3/SET9_F01_01.png
# SET9_F01_02.png SET9 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.3/SET9_F01_02.png
# Denoising SET : SET9, f_num : F01 End
# ====== F01 vs F02 v2_l1_on_img_gradient_0.8  ======
# ../weights/230414_find_lambda_FBI_Net_Grayscale_Samsung_SET050607080910x_as_F01_y_as_F02_l1_on_img_gradient_0.8_MSE_Affine_with_tv_layers_x17_filters_x64_cropsize_256.w
# folder_name :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.8
# ['F01']
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU =====
# ===== SET1 =====
# ===== SET2 =====
# ===== SET3 =====
# ===== SET4 =====
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung+SNU+dataset+221115 =====
# ===== SET10 =====
# F01  &  SET10_F01_01.png
# SET10 F01 (1, 2048, 3072)
# F01  &  SET10_F01_02.png
# SET10 F01 (1, 2048, 3072)
# ===== SET5 =====
# F01  &  SET5_F01_01.png
# SET5 F01 (1, 2048, 3072)
# F01  &  SET5_F01_02.png
# SET5 F01 (1, 2048, 3072)
# ===== SET6 =====
# F01  &  SET6_F01_01.png
# SET6 F01 (1, 2048, 3072)
# F01  &  SET6_F01_02.png
# SET6 F01 (1, 2048, 3072)
# ===== SET7 =====
# F01  &  SET7_F01_01.png
# SET7 F01 (1, 2048, 3072)
# F01  &  SET7_F01_02.png
# SET7 F01 (1, 2048, 3072)
# ===== SET8 =====
# F01  &  SET8_F01_01.png
# SET8 F01 (1, 2048, 3072)
# F01  &  SET8_F01_02.png
# SET8 F01 (1, 2048, 3072)
# ===== SET9 =====
# F01  &  SET9_F01_01.png
# SET9 F01 (1, 2048, 3072)
# F01  &  SET9_F01_02.png
# SET9 F01 (1, 2048, 3072)
# dict_keys(['SET1', 'SET2', 'SET3', 'SET4', 'SET10', 'SET5', 'SET6', 'SET7', 'SET8', 'SET9'])
#   dict_keys([])
#   dict_keys([])
#   dict_keys([])
#   dict_keys([])
#   dict_keys(['F01'])
#     dict_keys(['SET10_F01_01.png', 'SET10_F01_02.png'])
#   dict_keys(['F01'])
#     dict_keys(['SET5_F01_01.png', 'SET5_F01_02.png'])
#   dict_keys(['F01'])
#     dict_keys(['SET6_F01_01.png', 'SET6_F01_02.png'])
#   dict_keys(['F01'])
#     dict_keys(['SET7_F01_01.png', 'SET7_F01_02.png'])
#   dict_keys(['F01'])
#     dict_keys(['SET8_F01_01.png', 'SET8_F01_02.png'])
#   dict_keys(['F01'])
#     dict_keys(['SET9_F01_01.png', 'SET9_F01_02.png'])
# ====== load img_dict complete ======
# SET10_F01_01.png SET10 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.8/SET10_F01_01.png
# SET10_F01_02.png SET10 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.8/SET10_F01_02.png
# Denoising SET : SET10, f_num : F01 End
# SET5_F01_01.png SET5 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.8/SET5_F01_01.png
# SET5_F01_02.png SET5 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.8/SET5_F01_02.png
# Denoising SET : SET5, f_num : F01 End
# SET6_F01_01.png SET6 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.8/SET6_F01_01.png
# SET6_F01_02.png SET6 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.8/SET6_F01_02.png
# Denoising SET : SET6, f_num : F01 End
# SET7_F01_01.png SET7 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.8/SET7_F01_01.png
# SET7_F01_02.png SET7 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.8/SET7_F01_02.png
# Denoising SET : SET7, f_num : F01 End
# SET8_F01_01.png SET8 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.8/SET8_F01_01.png
# SET8_F01_02.png SET8 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.8/SET8_F01_02.png
# Denoising SET : SET8, f_num : F01 End
# SET9_F01_01.png SET9 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.8/SET9_F01_01.png
# SET9_F01_02.png SET9 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.8/SET9_F01_02.png
# Denoising SET : SET9, f_num : F01 End
# ====== F01 vs F02 v2_l1_on_img_gradient_0.1  ======
# ../weights/230414_find_lambda_FBI_Net_Grayscale_Samsung_SET050607080910x_as_F01_y_as_F02_l1_on_img_gradient_0.1_MSE_Affine_with_tv_layers_x17_filters_x64_cropsize_256.w
# folder_name :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.1
# ['F01']
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung_SNU =====
# ===== SET1 =====
# ===== SET2 =====
# ===== SET3 =====
# ===== SET4 =====
# ===== /home/hyunwoong/FBI-Denoiser/data/Samsung_tmp_dataset/Samsung+SNU+dataset+221115 =====
# ===== SET10 =====
# F01  &  SET10_F01_01.png
# SET10 F01 (1, 2048, 3072)
# F01  &  SET10_F01_02.png
# SET10 F01 (1, 2048, 3072)
# ===== SET5 =====
# F01  &  SET5_F01_01.png
# SET5 F01 (1, 2048, 3072)
# F01  &  SET5_F01_02.png
# SET5 F01 (1, 2048, 3072)
# ===== SET6 =====
# F01  &  SET6_F01_01.png
# SET6 F01 (1, 2048, 3072)
# F01  &  SET6_F01_02.png
# SET6 F01 (1, 2048, 3072)
# ===== SET7 =====
# F01  &  SET7_F01_01.png
# SET7 F01 (1, 2048, 3072)
# F01  &  SET7_F01_02.png
# SET7 F01 (1, 2048, 3072)
# ===== SET8 =====
# F01  &  SET8_F01_01.png
# SET8 F01 (1, 2048, 3072)
# F01  &  SET8_F01_02.png
# SET8 F01 (1, 2048, 3072)
# ===== SET9 =====
# F01  &  SET9_F01_01.png
# SET9 F01 (1, 2048, 3072)
# F01  &  SET9_F01_02.png
# SET9 F01 (1, 2048, 3072)
# dict_keys(['SET1', 'SET2', 'SET3', 'SET4', 'SET10', 'SET5', 'SET6', 'SET7', 'SET8', 'SET9'])
#   dict_keys([])
#   dict_keys([])
#   dict_keys([])
#   dict_keys([])
#   dict_keys(['F01'])
#     dict_keys(['SET10_F01_01.png', 'SET10_F01_02.png'])
#   dict_keys(['F01'])
#     dict_keys(['SET5_F01_01.png', 'SET5_F01_02.png'])
#   dict_keys(['F01'])
#     dict_keys(['SET6_F01_01.png', 'SET6_F01_02.png'])
#   dict_keys(['F01'])
#     dict_keys(['SET7_F01_01.png', 'SET7_F01_02.png'])
#   dict_keys(['F01'])
#     dict_keys(['SET8_F01_01.png', 'SET8_F01_02.png'])
#   dict_keys(['F01'])
#     dict_keys(['SET9_F01_01.png', 'SET9_F01_02.png'])
# ====== load img_dict complete ======
# SET10_F01_01.png SET10 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.1/SET10_F01_01.png
# SET10_F01_02.png SET10 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.1/SET10_F01_02.png
# Denoising SET : SET10, f_num : F01 End
# SET5_F01_01.png SET5 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.1/SET5_F01_01.png
# SET5_F01_02.png SET5 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.1/SET5_F01_02.png
# Denoising SET : SET5, f_num : F01 End
# SET6_F01_01.png SET6 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.1/SET6_F01_01.png
# SET6_F01_02.png SET6 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.1/SET6_F01_02.png
# Denoising SET : SET6, f_num : F01 End
# SET7_F01_01.png SET7 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.1/SET7_F01_01.png
# SET7_F01_02.png SET7 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.1/SET7_F01_02.png
# Denoising SET : SET7, f_num : F01 End
# SET8_F01_01.png SET8 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.1/SET8_F01_01.png
# SET8_F01_02.png SET8 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.1/SET8_F01_02.png
# Denoising SET : SET8, f_num : F01 End
# SET9_F01_01.png SET9 F01 0 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.1/SET9_F01_01.png
# SET9_F01_02.png SET9 F01 1 (1, 1, 2048, 3072)
# imwrite :  ./denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.1/SET9_F01_02.png
# Denoising SET : SET9, f_num : F01 End

# %%
folder_name
# Out:
# './denoised_img_F01_vs_F02_v2_l1_on_img_gradient_0.1'
